# %%
url='https://www.worldometers.info/coronavirus/'

# %%
# !pip install beautifulsoup4   tree ma conv garxa
# !pip install lxml
# !pip install requests   html lai reqst pathauxa
# !pip install pandas
# !pip install seaborn    Heatmap ko lagi =heatmap le color bar dinxa
# !pip install matplotlib   daigram/pichart ma draw garxa
# Out:
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python38\lib\site-packages (from requests) (3.4)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Installing collected packages: urllib3, charset-normalizer, certifi, requests
# Successfully installed certifi-2022.12.7 charset-normalizer-2.1.1 requests-2.28.1 urllib3-1.26.13
# WARNING: You are using pip version 21.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\users\hp\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import requests

# %%
html=requests.get(url).content

# %%
type(html)
# Out:
# bytes

# %%
from bs4 import BeautifulSoup

# %%
soup =BeautifulSoup(html,'html.parser')

# %%
tb=soup.find('tbody')

# %%
tr=tb.find_all('tr')

# %%
tr[9]
# Out:
# <tr style="">
# <td style="font-size:12px;color: grey;text-align:center;vertical-align:middle;">2</td>
# <td style="font-weight: bold; font-size:15px; text-align:left;"><a class="mt_a" href="country/india/">India</a></td>
# <td style="font-weight: bold; text-align:right">44,681,523</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="font-weight: bold; text-align:right;">530,722                                </td>
# <td style="font-weight: bold;
#                                     text-align:right;"></td>
# <td style="font-weight: bold; text-align:right">44,147,322</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="text-align:right;font-weight:bold;">3,479</td>
# <td style="font-weight: bold; text-align:right">698</td>
# <td style="font-weight: bold; text-align:right">31,765</td>
# <td style="font-weight: bold; text-align:right">377</td>
# <td style="font-weight: bold; text-align:right">912,362,106</td>
# <td style="font-weight: bold; text-align:right">648,615</td>
# <td style="font-weight: bold; text-align:right"><a href="/world-population/india-population/">1,406,631,776</a> </td>
# <td data-continent="Asia" style="display:none">Asia</td>
# <!-- 1 Case/Death/Test every X -->
# <td>31</td><td>2,650</td><td>2</td>
# <td style="font-weight: bold; text-align:right"></td>
# <td style="font-weight: bold; text-align:right"></td>
# <td style="font-weight: bold; text-align:right">2</td>
# </tr>

# %%
all_data=[]
for index in range(8,len(tr)):
    country_data=[]
    table_row=tr[index]
    table_data=table_row.find_all('td')
    
    for item in table_data:
        #print(item.text)
        country_data.append(item.text)
        
    all_data.append(country_data)

# %%
all_data
# Out:
# [['1',
#   'USA',
#   '103,151,843',
#   '',
#   '1,121,725                                ',
#   '',
#   '100,061,532',
#   '',
#   '1,968,586',
#   '4,815',
#   '308,095',
#   '3,350',
#   '1,155,997,944',
#   '3,452,747',
#   '334,805,269 ',
#   'North America',
#   '3',
#   '298',
#   '0',
#   '',
#   '',
#   '5,880'],
#  ['2',
#   'India',
#   '44,681,523',
#   '',
#   '530,722                                ',
#   '',
#   '44,147,322',
#   '',
#   '3,479',
#   '698',
#   '31,765',
#   '377',
#   '912,362,106',
#   '648,615',
#   '1,406,631,776 ',
#   'Asia',
#   '31',
#   '2,650',
#   '2',
#   '',
#   '',
#   '2'],
#  ['3',
#   'France',
#   '39,421,144',
#   '',
#   '163,105                                ',
#   '',
#   '38,862,625',
#   '',
#   '395,414',
#   '869',
#   '601,074',
#   '2,487',
#   '271,490,188',
#   '4,139,547',
#   '65,584,518 ',
#   'Europe',
#   '2',
#   '402',
#   '0',
#   '',
#   '',
#   '6,029'],
#  ['4',
#   'Germany',
#   '37,562,191',
#   '',
#   '163,244                                ',
#   '',
#   '36,946,600',
#   '+40,900',
#   '452,347',
#   '1,281',
#   '447,789',
#   '1,946',
#   '122,332,384',
#   '1,458,359',
#   '83,883,596 ',
#   'Europe',
#   '2',
#   '514',
#   '1',
#   '',
#   '',
#   '5,393'],
#  ['5',
#   'Brazil',
#   '36,560,497',
#   '',
#   '695,031                                ',
#   '',
#   '35,429,017',
#   '',
#   '436,449',
#   '8,318',
#   '169,770',
#   '3,227',
#   '63,776,166',
#   '296,146',
#   '215,353,593 ',
#   'South America',
#   '6',
#   '310',
#   '3',
#   '',
#   '',
#   '2,027'],
#  ['6',
#   'Japan',
#   '30,647,859',
#   '',
#   '60,411                                ',
#   '',
#   '21,271,832',
#   '',
#   '9,315,616',
#   '656',
#   '244,041',
#   '481',
#   '88,389,228',
#   '703,821',
#   '125,584,838 ',
#   'Asia',
#   '4',
#   '2,079',
#   '1',
#   '',
#   '',
#   '74,178'],
#  ['7',
#   'S. Korea',
#   '29,654,090',
#   '+54,343',
#   '32,745                                ',
#   '+76',
#   '28,567,938',
#   '+66,005',
#   '1,053,407',
#   '540',
#   '577,716',
#   '638',
#   '15,804,065',
#   '307,892',
#   '51,329,899 ',
#   'Asia',
#   '2',
#   '1,568',
#   '3',
#   '1,059',
#   '1',
#   '20,522'],
#  ['8',
#   'Italy',
#   '25,279,682',
#   '',
#   '185,417                                ',
#   '',
#   '24,688,083',
#   '',
#   '406,182',
#   '319',
#   '419,491',
#   '3,077',
#   '263,414,564',
#   '4,371,100',
#   '60,262,770 ',
#   'Europe',
#   '2',
#   '325',
#   '0',
#   '',
#   '',
#   '6,740'],
#  ['9',
#   'UK',
#   '24,210,131',
#   '',
#   '201,028                                ',
#   '',
#   '23,895,374',
#   '+6,508',
#   '113,729',
#   '146',
#   '353,443',
#   '2,935',
#   '522,526,476',
#   '7,628,357',
#   '68,497,907 ',
#   'Europe',
#   '3',
#   '341',
#   '0',
#   '',
#   '',
#   '1,660'],
#  ['10',
#   'Russia',
#   '21,832,768',
#   '',
#   '394,168                                ',
#   '',
#   '21,253,611',
#   '',
#   '184,989',
#   '2,300',
#   '149,739',
#   '2,703',
#   '273,400,000',
#   '1,875,095',
#   '145,805,947 ',
#   'Europe',
#   '7',
#   '370',
#   '1',
#   '',
#   '',
#   '1,269'],
#  ['11',
#   'Turkey',
#   '17,042,722',
#   '',
#   '101,492                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '199,186',
#   '1,186',
#   '162,743,369',
#   '1,902,052',
#   '85,561,976 ',
#   'Asia',
#   '5',
#   '843',
#   '1',
#   '',
#   '',
#   '1,819'],
#  ['12',
#   'Spain',
#   '13,693,478',
#   '',
#   '117,413                                ',
#   '',
#   '13,502,806',
#   '',
#   '73,259',
#   '231',
#   '293,102',
#   '2,513',
#   '471,036,328',
#   '10,082,298',
#   '46,719,142 ',
#   'Europe',
#   '3',
#   '398',
#   '0',
#   '',
#   '',
#   '1,568'],
#  ['13',
#   'Vietnam',
#   '11,525,911',
#   '',
#   '43,186                                ',
#   '',
#   '10,611,547',
#   '',
#   '871,178',
#   '12',
#   '116,478',
#   '436',
#   '85,826,548',
#   '867,342',
#   '98,953,541 ',
#   'Asia',
#   '9',
#   '2,291',
#   '1',
#   '',
#   '',
#   '8,804'],
#  ['14',
#   'Australia',
#   '11,211,305',
#   '+1,150',
#   '17,380                                ',
#   '+31',
#   '11,052,693',
#   '',
#   '141,232',
#   '109',
#   '430,066',
#   '667',
#   '78,835,048',
#   '3,024,116',
#   '26,068,792 ',
#   'Australia/Oceania',
#   '2',
#   '1,500',
#   '0',
#   '44',
#   '1',
#   '5,418'],
#  ['15',
#   'Argentina',
#   '10,004,679',
#   '',
#   '130,249                                ',
#   '',
#   '9,707,830',
#   '+8,843',
#   '166,600',
#   '402',
#   '217,445',
#   '2,831',
#   '35,716,069',
#   '776,264',
#   '46,010,234 ',
#   'South America',
#   '5',
#   '353',
#   '1',
#   '',
#   '',
#   '3,621'],
#  ['16',
#   'Taiwan',
#   '9,097,554',
#   '',
#   '15,608                                ',
#   '',
#   '8,609,056',
#   '',
#   '472,890',
#   '',
#   '380,833',
#   '653',
#   '29,584,266',
#   '1,238,426',
#   '23,888,595 ',
#   'Asia',
#   '3',
#   '1,531',
#   '1',
#   '',
#   '',
#   '19,796'],
#  ['17',
#   'Netherlands',
#   '8,576,523',
#   '',
#   '22,989                                ',
#   '',
#   '8,528,649',
#   '',
#   '24,885',
#   '55',
#   '498,303',
#   '1,336',
#   '25,984,435',
#   '1,509,718',
#   '17,211,447 ',
#   'Europe',
#   '2',
#   '749',
#   '1',
#   '',
#   '',
#   '1,446'],
#  ['18',
#   'Iran',
#   '7,562,169',
#   '',
#   '144,717                                ',
#   '',
#   '7,336,524',
#   '',
#   '80,928',
#   '167',
#   '87,909',
#   '1,682',
#   '54,420,785',
#   '632,632',
#   '86,022,837 ',
#   'Asia',
#   '11',
#   '594',
#   '2',
#   '',
#   '',
#   '941'],
#  ['19',
#   'Mexico',
#   '7,284,502',
#   '',
#   '331,333                                ',
#   '',
#   '6,519,926',
#   '',
#   '433,243',
#   '4,798',
#   '55,369',
#   '2,518',
#   '19,153,987',
#   '145,588',
#   '131,562,772 ',
#   'North America',
#   '18',
#   '397',
#   '7',
#   '',
#   '',
#   '3,293'],
#  ['20',
#   'Indonesia',
#   '6,724,281',
#   '',
#   '160,697                                ',
#   '',
#   '6,555,664',
#   '',
#   '7,920',
#   '2,771',
#   '24,090',
#   '576',
#   '114,158,919',
#   '408,975',
#   '279,134,505 ',
#   'Asia',
#   '42',
#   '1,737',
#   '2',
#   '',
#   '',
#   '28'],
#  ['21',
#   'Poland',
#   '6,371,866',
#   '',
#   '118,601                                ',
#   '',
#   '5,335,940',
#   '',
#   '917,325',
#   '1,192',
#   '168,837',
#   '3,143',
#   '38,031,207',
#   '1,007,722',
#   '37,739,785 ',
#   'Europe',
#   '6',
#   '318',
#   '1',
#   '',
#   '',
#   '24,307'],
#  ['22',
#   'Colombia',
#   '6,349,971',
#   '',
#   '142,259                                ',
#   '',
#   '6,170,360',
#   '',
#   '37,352',
#   '342',
#   '123,270',
#   '2,762',
#   '36,951,507',
#   '717,327',
#   '51,512,762 ',
#   'South America',
#   '8',
#   '362',
#   '1',
#   '',
#   '',
#   '725'],
#  ['23',
#   'Austria',
#   '5,731,160',
#   '',
#   '21,517                                ',
#   '',
#   '5,680,255',
#   '',
#   '29,388',
#   '',
#   '632,110',
#   '2,373',
#   '204,891,207',
#   '22,598,187',
#   '9,066,710 ',
#   'Europe',
#   '2',
#   '421',
#   '0',
#   '',
#   '',
#   '3,241'],
#  ['24',
#   'Portugal',
#   '5,557,941',
#   '',
#   '25,805                                ',
#   '',
#   '5,525,559',
#   '',
#   '6,577',
#   '61',
#   '548,090',
#   '2,545',
#   '45,855,210',
#   '4,521,956',
#   '10,140,570 ',
#   'Europe',
#   '2',
#   '393',
#   '0',
#   '',
#   '',
#   '649'],
#  ['25',
#   'Greece',
#   '5,548,487',
#   '',
#   '34,779                                ',
#   '',
#   '5,513,708',
#   '',
#   '0',
#   '115',
#   '537,819',
#   '3,371',
#   '102,228,365',
#   '9,909,078',
#   '10,316,637 ',
#   'Europe',
#   '2',
#   '297',
#   '0',
#   '',
#   '',
#   ''],
#  ['26',
#   'Ukraine',
#   '5,361,352',
#   '',
#   '110,859                                ',
#   '',
#   '5,243,879',
#   '+623',
#   '6,614',
#   '',
#   '124,128',
#   '2,567',
#   '32,603,805',
#   '754,855',
#   '43,192,122 ',
#   'Europe',
#   '8',
#   '390',
#   '1',
#   '',
#   '',
#   '153'],
#  ['27',
#   'Chile',
#   '5,071,034',
#   '',
#   '63,381                                ',
#   '',
#   '5,000,039',
#   '',
#   '7,614',
#   '113',
#   '263,428',
#   '3,292',
#   '47,843,453',
#   '2,485,349',
#   '19,250,195 ',
#   'South America',
#   '4',
#   '304',
#   '0',
#   '',
#   '',
#   '396'],
#  ['28',
#   'Malaysia',
#   '5,031,076',
#   '',
#   '36,892                                ',
#   '',
#   '4,982,772',
#   '',
#   '11,412',
#   '26',
#   '151,625',
#   '1,112',
#   '67,322,424',
#   '2,028,941',
#   '33,181,072 ',
#   'Asia',
#   '7',
#   '899',
#   '0',
#   '',
#   '',
#   '344'],
#  ['29',
#   'DPRK',
#   '4,772,813',
#   '',
#   '74                                ',
#   '',
#   '4,772,739',
#   '',
#   '0',
#   '',
#   '183,636',
#   '3',
#   '',
#   '',
#   '25,990,679 ',
#   'Asia',
#   '5',
#   '351,225',
#   '',
#   '',
#   '',
#   ''],
#  ['30',
#   'Israel',
#   '4,772,755',
#   '',
#   '12,101                                ',
#   '',
#   '4,750,133',
#   '',
#   '10,521',
#   '57',
#   '511,769',
#   '1,298',
#   '41,373,364',
#   '4,436,346',
#   '9,326,000 ',
#   'Asia',
#   '2',
#   '771',
#   '0',
#   '',
#   '',
#   '1,128'],
#  ['31',
#   'Thailand',
#   '4,724,916',
#   '',
#   '33,727                                ',
#   '',
#   '4,690,108',
#   '',
#   '1,081',
#   '1,496',
#   '67,423',
#   '481',
#   '17,270,775',
#   '246,450',
#   '70,078,203 ',
#   'Asia',
#   '15',
#   '2,078',
#   '4',
#   '',
#   '',
#   '15'],
#  ['32',
#   'Belgium',
#   '4,682,234',
#   '',
#   '33,395                                ',
#   '',
#   '4,619,471',
#   '+1,608',
#   '29,368',
#   '97',
#   '401,279',
#   '2,862',
#   '36,436,600',
#   '3,122,706',
#   '11,668,278 ',
#   'Europe',
#   '2',
#   '349',
#   '0',
#   '',
#   '',
#   '2,517'],
#  ['33',
#   'Czechia',
#   '4,583,646',
#   '',
#   '42,220                                ',
#   '',
#   '4,536,834',
#   '',
#   '4,592',
#   '42',
#   '426,911',
#   '3,932',
#   '56,821,170',
#   '5,292,196',
#   '10,736,784 ',
#   'Europe',
#   '2',
#   '254',
#   '0',
#   '',
#   '',
#   '428'],
#  ['34',
#   'Canada',
#   '4,508,275',
#   '',
#   '49,566                                ',
#   '',
#   '4,393,634',
#   '+2,361',
#   '65,075',
#   '99',
#   '117,438',
#   '1,291',
#   '66,343,123',
#   '1,728,207',
#   '38,388,419 ',
#   'North America',
#   '9',
#   '774',
#   '1',
#   '',
#   '',
#   '1,695'],
#  ['35',
#   'Peru',
#   '4,470,919',
#   '',
#   '218,414                                ',
#   '',
#   '4,232,661',
#   '',
#   '19,844',
#   '101',
#   '132,730',
#   '6,484',
#   '37,495,286',
#   '1,113,141',
#   '33,684,208 ',
#   'South America',
#   '8',
#   '154',
#   '1',
#   '',
#   '',
#   '589'],
#  ['36',
#   'Switzerland',
#   '4,382,359',
#   '',
#   '14,388                                ',
#   '',
#   '4,334,688',
#   '+1,242',
#   '33,283',
#   '63',
#   '499,492',
#   '1,640',
#   '23,292,004',
#   '2,654,772',
#   '8,773,637 ',
#   'Europe',
#   '2',
#   '610',
#   '0',
#   '',
#   '',
#   '3,794'],
#  ['37',
#   'Philippines',
#   '4,068,425',
#   '',
#   '65,498                                ',
#   '',
#   '3,991,071',
#   '',
#   '11,856',
#   '162',
#   '36,161',
#   '582',
#   '34,103,953',
#   '303,122',
#   '112,508,994 ',
#   'Asia',
#   '28',
#   '1,718',
#   '3',
#   '',
#   '',
#   '105'],
#  ['38',
#   'South Africa',
#   '4,050,288',
#   '',
#   '102,568                                ',
#   '',
#   '3,912,506',
#   '',
#   '35,214',
#   '192',
#   '66,665',
#   '1,688',
#   '26,473,049',
#   '435,726',
#   '60,756,135 ',
#   'Africa',
#   '15',
#   '592',
#   '2',
#   '',
#   '',
#   '580'],
#  ['39',
#   'Romania',
#   '3,316,192',
#   '',
#   '67,460                                ',
#   '',
#   '3,241,020',
#   '+3,432',
#   '7,712',
#   '109',
#   '174,249',
#   '3,545',
#   '26,158,689',
#   '1,374,506',
#   '19,031,335 ',
#   'Europe',
#   '6',
#   '282',
#   '1',
#   '',
#   '',
#   '405'],
#  ['40',
#   'Denmark',
#   '3,170,881',
#   '',
#   '7,941                                ',
#   '',
#   '3,156,224',
#   '',
#   '6,716',
#   '14',
#   '543,429',
#   '1,361',
#   '129,079,953',
#   '22,121,861',
#   '5,834,950 ',
#   'Europe',
#   '2',
#   '735',
#   '0',
#   '',
#   '',
#   '1,151'],
#  ['41',
#   'Hong Kong',
#   '2,790,960',
#   '',
#   '12,481                                ',
#   '',
#   '2,155,003',
#   '',
#   '623,476',
#   '47',
#   '367,024',
#   '1,641',
#   '75,375,235',
#   '9,912,187',
#   '7,604,299 ',
#   'Asia',
#   '3',
#   '609',
#   '0',
#   '',
#   '',
#   '81,990'],
#  ['42',
#   'Sweden',
#   '2,683,356',
#   '',
#   '22,110                                ',
#   '',
#   '2,623,235',
#   '+544',
#   '38,011',
#   '43',
#   '262,586',
#   '2,164',
#   '19,333,094',
#   '1,891,883',
#   '10,218,971 ',
#   'Europe',
#   '4',
#   '462',
#   '1',
#   '',
#   '',
#   '3,720'],
#  ['43',
#   'Iraq',
#   '2,465,545',
#   '',
#   '25,375                                ',
#   '',
#   '2,439,497',
#   '',
#   '673',
#   '21',
#   '58,474',
#   '602',
#   '19,544,451',
#   '463,523',
#   '42,164,965 ',
#   'Asia',
#   '17',
#   '1,662',
#   '2',
#   '',
#   '',
#   '16'],
#  ['44',
#   'Serbia',
#   '2,455,236',
#   '',
#   '17,574                                ',
#   '',
#   '2,421,479',
#   '',
#   '16,183',
#   '23',
#   '283,743',
#   '2,031',
#   '11,957,115',
#   '1,381,844',
#   '8,653,016 ',
#   'Europe',
#   '4',
#   '492',
#   '1',
#   '',
#   '',
#   '1,870'],
#  ['45',
#   'Singapore',
#   '2,209,511',
#   '',
#   '1,714                                ',
#   '',
#   '2,135,949',
#   '',
#   '71,848',
#   '2',
#   '371,750',
#   '288',
#   '24,755,451',
#   '4,165,098',
#   '5,943,546 ',
#   'Asia',
#   '3',
#   '3,468',
#   '0',
#   '',
#   '',
#   '12,088'],
#  ['46',
#   'Hungary',
#   '2,188,737',
#   '',
#   '48,546                                ',
#   '',
#   '2,127,121',
#   '',
#   '13,070',
#   '16',
#   '227,845',
#   '5,054',
#   '11,394,556',
#   '1,186,160',
#   '9,606,259 ',
#   'Europe',
#   '4',
#   '198',
#   '1',
#   '',
#   '',
#   '1,361'],
#  ['47',
#   'New Zealand',
#   '2,138,754',
#   '',
#   '3,621                                ',
#   '',
#   '2,114,718',
#   '',
#   '20,415',
#   '',
#   '436,641',
#   '739',
#   '7,710,637',
#   '1,574,177',
#   '4,898,203 ',
#   'Australia/Oceania',
#   '2',
#   '1,353',
#   '1',
#   '',
#   '',
#   '4,168'],
#  ['48',
#   'Bangladesh',
#   '2,037,305',
#   '',
#   '29,440                                ',
#   '',
#   '1,988,846',
#   '',
#   '19,019',
#   '1,331',
#   '12,135',
#   '175',
#   '15,168,571',
#   '90,351',
#   '167,885,689 ',
#   'Asia',
#   '82',
#   '5,703',
#   '11',
#   '',
#   '',
#   '113'],
#  ['49',
#   'Slovakia',
#   '1,859,788',
#   '',
#   '20,855                                ',
#   '',
#   '1,837,892',
#   '',
#   '1,041',
#   '28',
#   '340,608',
#   '3,819',
#   '7,378,960',
#   '1,351,410',
#   '5,460,193 ',
#   'Europe',
#   '3',
#   '262',
#   '1',
#   '',
#   '',
#   '191'],
#  ['50',
#   'Georgia',
#   '1,809,359',
#   '',
#   '16,899                                ',
#   '',
#   '1,776,548',
#   '',
#   '15,912',
#   '',
#   '455,903',
#   '4,258',
#   '16,920,079',
#   '4,263,340',
#   '3,968,738 ',
#   'Asia',
#   '2',
#   '235',
#   '0',
#   '',
#   '',
#   '4,009'],
#  ['51',
#   'Jordan',
#   '1,746,997',
#   '',
#   '14,122                                ',
#   '',
#   '1,731,007',
#   '',
#   '1,868',
#   '59',
#   '169,597',
#   '1,371',
#   '17,201,885',
#   '1,669,945',
#   '10,300,869 ',
#   'Asia',
#   '6',
#   '729',
#   '1',
#   '',
#   '',
#   '181'],
#  ['52',
#   'Ireland',
#   '1,693,847',
#   '',
#   '8,339                                ',
#   '',
#   '1,675,433',
#   '+53',
#   '10,075',
#   '36',
#   '337,406',
#   '1,661',
#   '12,945,996',
#   '2,578,781',
#   '5,020,199 ',
#   'Europe',
#   '3',
#   '602',
#   '0',
#   '',
#   '',
#   '2,007'],
#  ['53',
#   'Pakistan',
#   '1,575,992',
#   '+15',
#   '30,639                                ',
#   '',
#   '1,538,689',
#   '',
#   '6,664',
#   '17',
#   '6,867',
#   '134',
#   '30,570,862',
#   '133,213',
#   '229,488,994 ',
#   'Asia',
#   '146',
#   '7,490',
#   '8',
#   '0.07',
#   '',
#   '29'],
#  ['54',
#   'Norway',
#   '1,476,541',
#   '',
#   '4,571                                ',
#   '',
#   '1,469,346',
#   '',
#   '2,624',
#   '20',
#   '267,908',
#   '829',
#   '11,002,430',
#   '1,996,315',
#   '5,511,370 ',
#   'Europe',
#   '4',
#   '1,206',
#   '1',
#   '',
#   '',
#   '476'],
#  ['55',
#   'Finland',
#   '1,446,397',
#   '',
#   '8,263                                ',
#   '',
#   '1,425,662',
#   '+1,317',
#   '12,472',
#   '21',
#   '260,379',
#   '1,487',
#   '11,984,148',
#   '2,157,378',
#   '5,554,960 ',
#   'Europe',
#   '4',
#   '672',
#   '0',
#   '',
#   '',
#   '2,245'],
#  ['56',
#   'Kazakhstan',
#   '1,404,504',
#   '+175',
#   '13,695                                ',
#   '',
#   '1,383,020',
#   '',
#   '7,789',
#   '24',
#   '73,132',
#   '713',
#   '11,575,012',
#   '602,707',
#   '19,205,043 ',
#   'Asia',
#   '14',
#   '1,402',
#   '2',
#   '9',
#   '',
#   '406'],
#  ['57',
#   'Slovenia',
#   '1,315,101',
#   '',
#   '7,029                                ',
#   '',
#   '1,294,252',
#   '',
#   '13,820',
#   '21',
#   '632,858',
#   '3,383',
#   '2,812,824',
#   '1,353,599',
#   '2,078,034 ',
#   'Europe',
#   '2',
#   '296',
#   '1',
#   '',
#   '',
#   '6,651'],
#  ['58',
#   'Bulgaria',
#   '1,293,684',
#   '',
#   '38,130                                ',
#   '',
#   '1,251,436',
#   '',
#   '4,118',
#   '41',
#   '189,008',
#   '5,571',
#   '10,927,911',
#   '1,596,575',
#   '6,844,597 ',
#   'Europe',
#   '5',
#   '180',
#   '1',
#   '',
#   '',
#   '602'],
#  ['59',
#   'Lithuania',
#   '1,291,464',
#   '',
#   '9,505                                ',
#   '',
#   '1,275,308',
#   '',
#   '6,651',
#   '8',
#   '485,201',
#   '3,571',
#   '10,328,062',
#   '3,880,239',
#   '2,661,708 ',
#   'Europe',
#   '2',
#   '280',
#   '0',
#   '',
#   '',
#   '2,499'],
#  ['60',
#   'Morocco',
#   '1,271,942',
#   '',
#   '16,295                                ',
#   '',
#   '1,255,319',
#   '',
#   '328',
#   '293',
#   '33,674',
#   '431',
#   '12,883,597',
#   '341,082',
#   '37,772,756 ',
#   'Africa',
#   '30',
#   '2,318',
#   '3',
#   '',
#   '',
#   '9'],
#  ['61',
#   'Croatia',
#   '1,265,719',
#   '',
#   '17,719                                ',
#   '',
#   '1,246,601',
#   '',
#   '1,399',
#   '29',
#   '311,808',
#   '4,365',
#   '5,442,774',
#   '1,340,821',
#   '4,059,286 ',
#   'Europe',
#   '3',
#   '229',
#   '1',
#   '',
#   '',
#   '345'],
#  ['62',
#   'Lebanon',
#   '1,224,238',
#   '',
#   '10,756                                ',
#   '',
#   '1,087,587',
#   '',
#   '125,895',
#   '74',
#   '183,136',
#   '1,609',
#   '4,795,578',
#   '717,380',
#   '6,684,849 ',
#   'Asia',
#   '5',
#   '621',
#   '1',
#   '',
#   '',
#   '18,833'],
#  ['63',
#   'Guatemala',
#   '1,213,139',
#   '',
#   '20,027                                ',
#   '',
#   '1,179,448',
#   '',
#   '13,664',
#   '5',
#   '65,279',
#   '1,078',
#   '6,610,646',
#   '355,716',
#   '18,584,039 ',
#   'North America',
#   '15',
#   '928',
#   '3',
#   '',
#   '',
#   '735'],
#  ['64',
#   'Bolivia',
#   '1,174,694',
#   '+1,555',
#   '22,324                                ',
#   '+1',
#   '1,123,744',
#   '+1,249',
#   '28,626',
#   '220',
#   '97,951',
#   '1,861',
#   '2,705,422',
#   '225,590',
#   '11,992,656 ',
#   'South America',
#   '10',
#   '537',
#   '4',
#   '130',
#   '0.08',
#   '2,387'],
#  ['65',
#   'Costa Rica',
#   '1,171,802',
#   '',
#   '9,104                                ',
#   '',
#   '860,711',
#   '',
#   '301,987',
#   '52',
#   '226,114',
#   '1,757',
#   '4,659,757',
#   '899,158',
#   '5,182,354 ',
#   'North America',
#   '4',
#   '569',
#   '1',
#   '',
#   '',
#   '58,272'],
#  ['66',
#   'Tunisia',
#   '1,147,729',
#   '',
#   '29,288                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '44',
#   '95,274',
#   '2,431',
#   '4,986,390',
#   '413,923',
#   '12,046,656 ',
#   'Africa',
#   '10',
#   '411',
#   '2',
#   '',
#   '',
#   '701'],
#  ['67',
#   'Cuba',
#   '1,112,197',
#   '',
#   '8,530                                ',
#   '',
#   '1,103,508',
#   '',
#   '159',
#   '23',
#   '98,375',
#   '754',
#   '14,276,770',
#   '1,262,799',
#   '11,305,652 ',
#   'North America',
#   '10',
#   '1,325',
#   '1',
#   '',
#   '',
#   '14'],
#  ['68',
#   'UAE',
#   '1,047,694',
#   '',
#   '2,348                                ',
#   '',
#   '1,030,711',
#   '',
#   '14,635',
#   '',
#   '103,919',
#   '233',
#   '198,152,741',
#   '19,654,530',
#   '10,081,785 ',
#   'Asia',
#   '10',
#   '4,294',
#   '0',
#   '',
#   '',
#   '1,452'],
#  ['69',
#   'Ecuador',
#   '1,040,463',
#   '',
#   '35,940                                ',
#   '',
#   '1,003,412',
#   '+1,110',
#   '1,111',
#   '759',
#   '57,442',
#   '1,984',
#   '3,082,403',
#   '170,173',
#   '18,113,361 ',
#   'South America',
#   '17',
#   '504',
#   '6',
#   '',
#   '',
#   '61'],
#  ['70',
#   'Panama',
#   '1,027,247',
#   '',
#   '8,584                                ',
#   '',
#   '1,016,577',
#   '',
#   '2,086',
#   '16',
#   '231,000',
#   '1,930',
#   '7,422,622',
#   '1,669,144',
#   '4,446,964 ',
#   'North America',
#   '4',
#   '518',
#   '1',
#   '',
#   '',
#   '469'],
#  ['71',
#   'Uruguay',
#   '1,025,810',
#   '',
#   '7,586                                ',
#   '',
#   '1,013,059',
#   '',
#   '5,165',
#   '18',
#   '293,423',
#   '2,170',
#   '6,114,822',
#   '1,749,083',
#   '3,496,016 ',
#   'South America',
#   '3',
#   '461',
#   '1',
#   '',
#   '',
#   '1,477'],
#  ['72',
#   'Mongolia',
#   '1,007,787',
#   '',
#   '2,179                                ',
#   '',
#   '1,005,087',
#   '',
#   '521',
#   '192',
#   '298,331',
#   '645',
#   '4,030,048',
#   '1,193,000',
#   '3,378,078 ',
#   'Asia',
#   '3',
#   '1,550',
#   '1',
#   '',
#   '',
#   '154'],
#  ['73',
#   'Nepal',
#   '1,001,031',
#   '',
#   '12,020                                ',
#   '',
#   '988,986',
#   '',
#   '25',
#   '',
#   '33,119',
#   '398',
#   '5,994,517',
#   '198,326',
#   '30,225,582 ',
#   'Asia',
#   '30',
#   '2,515',
#   '5',
#   '',
#   '',
#   '0.8'],
#  ['74',
#   'Belarus',
#   '994,037',
#   '',
#   '7,118                                ',
#   '',
#   '985,592',
#   '',
#   '1,327',
#   '',
#   '105,381',
#   '755',
#   '13,646,641',
#   '1,446,722',
#   '9,432,800 ',
#   'Europe',
#   '9',
#   '1,325',
#   '1',
#   '',
#   '',
#   '141'],
#  ['75',
#   'Latvia',
#   '974,744',
#   '',
#   '6,181                                ',
#   '',
#   '966,958',
#   '',
#   '1,605',
#   '13',
#   '527,220',
#   '3,343',
#   '7,852,419',
#   '4,247,221',
#   '1,848,837 ',
#   'Europe',
#   '2',
#   '299',
#   '0',
#   '',
#   '',
#   '868'],
#  ['76',
#   'Saudi Arabia',
#   '827,275',
#   '',
#   '9,534                                ',
#   '',
#   '814,911',
#   '',
#   '2,830',
#   '25',
#   '23,079',
#   '266',
#   '44,974,222',
#   '1,254,689',
#   '35,844,909 ',
#   'Asia',
#   '43',
#   '3,760',
#   '1',
#   '',
#   '',
#   '79'],
#  ['77',
#   'Azerbaijan',
#   '826,993',
#   '',
#   '10,027                                ',
#   '',
#   '816,434',
#   '',
#   '532',
#   '',
#   '80,289',
#   '973',
#   '7,444,231',
#   '722,726',
#   '10,300,205 ',
#   'Asia',
#   '12',
#   '1,027',
#   '1',
#   '',
#   '',
#   '52'],
#  ['78',
#   'Paraguay',
#   '798,231',
#   '',
#   '19,716                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '109,259',
#   '2,699',
#   '2,657,506',
#   '363,751',
#   '7,305,843 ',
#   'South America',
#   '9',
#   '371',
#   '3',
#   '',
#   '',
#   '10,977'],
#  ['79',
#   'Bahrain',
#   '699,313',
#   '',
#   '1,539                                ',
#   '',
#   '697,225',
#   '',
#   '549',
#   '2,405',
#   '391,995',
#   '863',
#   '10,650,823',
#   '5,970,249',
#   '1,783,983 ',
#   'Asia',
#   '3',
#   '1,159',
#   '0',
#   '',
#   '',
#   '308'],
#  ['80',
#   'Sri Lanka',
#   '671,942',
#   '',
#   '16,820                                ',
#   '',
#   '655,081',
#   '',
#   '41',
#   '',
#   '31,143',
#   '780',
#   '6,486,117',
#   '300,619',
#   '21,575,842 ',
#   'Asia',
#   '32',
#   '1,283',
#   '3',
#   '',
#   '',
#   '2'],
#  ['81',
#   'Kuwait',
#   '662,747',
#   '',
#   '2,570                                ',
#   '',
#   '660,095',
#   '',
#   '82',
#   '',
#   '151,301',
#   '587',
#   '8,447,300',
#   '1,928,464',
#   '4,380,326 ',
#   'Asia',
#   '7',
#   '1,704',
#   '1',
#   '',
#   '',
#   '19'],
#  ['82',
#   'Dominican Republic',
#   '650,990',
#   '',
#   '4,384                                ',
#   '',
#   '644,785',
#   '',
#   '1,821',
#   '4',
#   '58,879',
#   '397',
#   '3,740,928',
#   '338,350',
#   '11,056,370 ',
#   'North America',
#   '17',
#   '2,522',
#   '3',
#   '',
#   '',
#   '165'],
#  ['83',
#   'Cyprus',
#   '634,709',
#   '',
#   '1,262                                ',
#   '',
#   '624,300',
#   '',
#   '9,147',
#   '60',
#   '518,813',
#   '1,032',
#   '9,640,118',
#   '7,879,860',
#   '1,223,387 ',
#   'Asia',
#   '2',
#   '969',
#   '0',
#   '',
#   '',
#   '7,477'],
#  ['84',
#   'Myanmar',
#   '633,726',
#   '',
#   '19,490                                ',
#   '',
#   '614,165',
#   '',
#   '71',
#   '',
#   '11,475',
#   '353',
#   '9,858,210',
#   '178,503',
#   '55,227,143 ',
#   'Asia',
#   '87',
#   '2,834',
#   '6',
#   '',
#   '',
#   '1'],
#  ['85',
#   'Palestine',
#   '621,008',
#   '',
#   '5,404                                ',
#   '',
#   '615,445',
#   '',
#   '159',
#   '17',
#   '116,173',
#   '1,011',
#   '3,078,533',
#   '575,907',
#   '5,345,541 ',
#   'Asia',
#   '9',
#   '989',
#   '2',
#   '',
#   '',
#   '30'],
#  ['86',
#   'Estonia',
#   '612,829',
#   '',
#   '2,885                                ',
#   '',
#   '524,990',
#   '',
#   '84,954',
#   '9',
#   '463,594',
#   '2,182',
#   '3,643,453',
#   '2,756,204',
#   '1,321,910 ',
#   'Europe',
#   '2',
#   '458',
#   '0',
#   '',
#   '',
#   '64,266'],
#  ['87',
#   'Moldova',
#   '597,216',
#   '',
#   '11,940                                ',
#   '',
#   '504,142',
#   '',
#   '81,134',
#   '49',
#   '148,814',
#   '2,975',
#   '3,216,305',
#   '801,437',
#   '4,013,171 ',
#   'Europe',
#   '7',
#   '336',
#   '1',
#   '',
#   '',
#   '20,217'],
#  ['88',
#   'Venezuela',
#   '550,779',
#   '',
#   '5,834                                ',
#   '',
#   '544,198',
#   '',
#   '747',
#   '36',
#   '18,819',
#   '199',
#   '3,359,014',
#   '114,771',
#   '29,266,991 ',
#   'South America',
#   '53',
#   '5,017',
#   '9',
#   '',
#   '',
#   '26'],
#  ['89',
#   'Egypt',
#   '515,645',
#   '',
#   '24,613                                ',
#   '',
#   '442,182',
#   '',
#   '48,850',
#   '122',
#   '4,857',
#   '232',
#   '3,693,367',
#   '34,792',
#   '106,156,692 ',
#   'Africa',
#   '206',
#   '4,313',
#   '29',
#   '',
#   '',
#   '460'],
#  ['90',
#   'Libya',
#   '507,153',
#   '',
#   '6,437                                ',
#   '',
#   '500,675',
#   '',
#   '41',
#   '',
#   '72,031',
#   '914',
#   '2,483,446',
#   '352,725',
#   '7,040,745 ',
#   'Africa',
#   '14',
#   '1,094',
#   '3',
#   '',
#   '',
#   '6'],
#  ['91',
#   'Ethiopia',
#   '498,832',
#   '',
#   '7,572                                ',
#   '',
#   '483,654',
#   '',
#   '7,606',
#   '',
#   '4,129',
#   '63',
#   '5,434,732',
#   '44,985',
#   '120,812,698 ',
#   'Africa',
#   '242',
#   '15,955',
#   '22',
#   '',
#   '',
#   '63'],
#  ['92',
#   'Qatar',
#   '490,946',
#   '',
#   '685                                ',
#   '',
#   '489,705',
#   '',
#   '556',
#   '1',
#   '164,752',
#   '230',
#   '4,065,369',
#   '1,364,257',
#   '2,979,915 ',
#   'Asia',
#   '6',
#   '4,350',
#   '1',
#   '',
#   '',
#   '187'],
#  ['93',
#   'Réunion',
#   '480,501',
#   '',
#   '907                                ',
#   '',
#   '418,572',
#   '',
#   '61,022',
#   '10',
#   '529,151',
#   '999',
#   '1,603,660',
#   '1,766,027',
#   '908,061 ',
#   'Africa',
#   '2',
#   '1,001',
#   '1',
#   '',
#   '',
#   '67,200'],
#  ['94',
#   'Honduras',
#   '468,048',
#   '',
#   '11,088                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '105',
#   '45,792',
#   '1,085',
#   '1,602,425',
#   '156,774',
#   '10,221,247 ',
#   'North America',
#   '22',
#   '922',
#   '6',
#   '',
#   '',
#   '31,739'],
#  ['95',
#   'Armenia',
#   '445,976',
#   '',
#   '8,716                                ',
#   '',
#   '435,162',
#   '',
#   '2,098',
#   '',
#   '150,061',
#   '2,933',
#   '3,242,901',
#   '1,091,164',
#   '2,971,966 ',
#   'Asia',
#   '7',
#   '341',
#   '1',
#   '',
#   '',
#   '706'],
#  ['96',
#   'Bosnia and Herzegovina',
#   '401,125',
#   '',
#   '16,239                                ',
#   '',
#   '378,880',
#   '',
#   '6,006',
#   '',
#   '123,449',
#   '4,998',
#   '1,882,857',
#   '579,462',
#   '3,249,317 ',
#   'Europe',
#   '8',
#   '200',
#   '2',
#   '',
#   '',
#   '1,848'],
#  ['97',
#   'Oman',
#   '399,154',
#   '',
#   '4,260                                ',
#   '',
#   '384,669',
#   '',
#   '10,225',
#   '2',
#   '74,973',
#   '800',
#   '25,000,000',
#   '4,695,724',
#   '5,323,993 ',
#   'Asia',
#   '13',
#   '1,250',
#   '0',
#   '',
#   '',
#   '1,921'],
#  ['98',
#   'North Macedonia',
#   '346,095',
#   '',
#   '9,623                                ',
#   '',
#   '336,215',
#   '',
#   '257',
#   '',
#   '166,288',
#   '4,624',
#   '2,210,818',
#   '1,062,227',
#   '2,081,304 ',
#   'Europe',
#   '6',
#   '216',
#   '1',
#   '',
#   '',
#   '123'],
#  ['99',
#   'Kenya',
#   '342,617',
#   '',
#   '5,688                                ',
#   '',
#   '336,811',
#   '',
#   '118',
#   '1',
#   '6,095',
#   '101',
#   '3,961,814',
#   '70,476',
#   '56,215,221 ',
#   'Africa',
#   '164',
#   '9,883',
#   '14',
#   '',
#   '',
#   '2'],
#  ['100',
#   'Zambia',
#   '335,980',
#   '',
#   '4,030                                ',
#   '',
#   '330,635',
#   '',
#   '1,315',
#   '',
#   '17,256',
#   '207',
#   '3,803,176',
#   '195,333',
#   '19,470,234 ',
#   'Africa',
#   '58',
#   '4,831',
#   '5',
#   '',
#   '',
#   '68'],
#  ['101',
#   'Albania',
#   '333,995',
#   '',
#   '3,595                                ',
#   '',
#   '328,719',
#   '',
#   '1,681',
#   '',
#   '116,522',
#   '1,254',
#   '1,941,032',
#   '677,173',
#   '2,866,374 ',
#   'Europe',
#   '9',
#   '797',
#   '1',
#   '',
#   '',
#   '586'],
#  ['102',
#   'Botswana',
#   '328,230',
#   '',
#   '2,795                                ',
#   '',
#   '323,747',
#   '',
#   '1,688',
#   '1',
#   '134,456',
#   '1,145',
#   '2,026,898',
#   '830,300',
#   '2,441,162 ',
#   'Africa',
#   '7',
#   '873',
#   '1',
#   '',
#   '',
#   '691'],
#  ['103',
#   'Luxembourg',
#   '297,757',
#   '',
#   '1,133                                ',
#   '',
#   '288,991',
#   '',
#   '7,633',
#   '',
#   '463,528',
#   '1,764',
#   '4,412,567',
#   '6,869,188',
#   '642,371 ',
#   'Europe',
#   '2',
#   '567',
#   '0',
#   '',
#   '',
#   '11,883'],
#  ['104',
#   'Montenegro',
#   '285,247',
#   '',
#   '2,792                                ',
#   '',
#   '281,969',
#   '',
#   '486',
#   '6',
#   '454,251',
#   '4,446',
#   '2,684,180',
#   '4,274,512',
#   '627,950 ',
#   'Europe',
#   '2',
#   '225',
#   '0',
#   '',
#   '',
#   '774'],
#  ['105',
#   'Algeria',
#   '271,262',
#   '',
#   '6,881                                ',
#   '',
#   '182,671',
#   '',
#   '81,710',
#   '',
#   '5,982',
#   '152',
#   '230,861',
#   '5,091',
#   '45,350,148 ',
#   'Africa',
#   '167',
#   '6,591',
#   '196',
#   '',
#   '',
#   '1,802'],
#  ['106',
#   'Brunei ',
#   '270,199',
#   '',
#   '225                                ',
#   '',
#   '243,601',
#   '',
#   '26,373',
#   '3',
#   '606,601',
#   '505',
#   '717,784',
#   '1,611,437',
#   '445,431 ',
#   'Asia',
#   '2',
#   '1,980',
#   '1',
#   '',
#   '',
#   '59,208'],
#  ['107',
#   'Nigeria',
#   '266,463',
#   '',
#   '3,155                                ',
#   '',
#   '259,850',
#   '',
#   '3,458',
#   '11',
#   '1,229',
#   '15',
#   '5,708,974',
#   '26,339',
#   '216,746,934 ',
#   'Africa',
#   '813',
#   '68,700',
#   '38',
#   '',
#   '',
#   '16'],
#  ['108',
#   'Zimbabwe',
#   '259,981',
#   '',
#   '5,637                                ',
#   '',
#   '253,677',
#   '',
#   '667',
#   '12',
#   '16,957',
#   '368',
#   '2,525,756',
#   '164,744',
#   '15,331,428 ',
#   'Africa',
#   '59',
#   '2,720',
#   '6',
#   '',
#   '',
#   '44'],
#  ['109',
#   'Uzbekistan',
#   '250,066',
#   '',
#   '1,637                                ',
#   '',
#   '241,486',
#   '',
#   '6,943',
#   '23',
#   '7,273',
#   '48',
#   '1,377,915',
#   '40,077',
#   '34,382,084 ',
#   'Asia',
#   '137',
#   '21,003',
#   '25',
#   '',
#   '',
#   '202'],
#  ['110',
#   'Mozambique',
#   '231,219',
#   '',
#   '2,232                                ',
#   '',
#   '228,801',
#   '',
#   '186',
#   '11',
#   '6,988',
#   '67',
#   '1,371,127',
#   '41,437',
#   '33,089,461 ',
#   'Africa',
#   '143',
#   '14,825',
#   '24',
#   '',
#   '',
#   '6'],
#  ['111',
#   'Martinique',
#   '228,171',
#   '',
#   '1,085                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '8',
#   '609,941',
#   '2,900',
#   '828,928',
#   '2,215,870',
#   '374,087 ',
#   'North America',
#   '2',
#   '345',
#   '0',
#   '',
#   '',
#   '606,763'],
#  ['112',
#   'Laos',
#   '217,901',
#   '+14',
#   '758                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '29,127',
#   '101',
#   '1,233,207',
#   '164,845',
#   '7,481,023 ',
#   'Asia',
#   '34',
#   '9,869',
#   '6',
#   '2',
#   '',
#   '28,002'],
#  ['113',
#   'Iceland',
#   '208,459',
#   '',
#   '229                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '2',
#   '603,541',
#   '663',
#   '1,996,384',
#   '5,780,036',
#   '345,393 ',
#   'Europe',
#   '2',
#   '1,508',
#   '0',
#   '',
#   '',
#   '383,751'],
#  ['114',
#   'Afghanistan',
#   '207,866',
#   '',
#   '7,854                                ',
#   '',
#   '185,747',
#   '',
#   '14,265',
#   '1,124',
#   '5,100',
#   '193',
#   '1,181,500',
#   '28,991',
#   '40,754,388 ',
#   'Asia',
#   '196',
#   '5,189',
#   '34',
#   '',
#   '',
#   '350'],
#  ['115',
#   'Kyrgyzstan',
#   '206,586',
#   '',
#   '2,991                                ',
#   '',
#   '196,406',
#   '',
#   '7,189',
#   '131',
#   '30,704',
#   '445',
#   '1,907,195',
#   '283,460',
#   '6,728,271 ',
#   'Asia',
#   '33',
#   '2,250',
#   '4',
#   '',
#   '',
#   '1,068'],
#  ['116',
#   'El Salvador',
#   '201,785',
#   '',
#   '4,230                                ',
#   '',
#   '179,410',
#   '',
#   '18,145',
#   '8',
#   '30,805',
#   '646',
#   '2,610,114',
#   '398,467',
#   '6,550,389 ',
#   'North America',
#   '32',
#   '1,549',
#   '3',
#   '',
#   '',
#   '2,770'],
#  ['117',
#   'Guadeloupe',
#   '200,965',
#   '',
#   '1,003                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '19',
#   '502,671',
#   '2,509',
#   '938,039',
#   '2,346,306',
#   '399,794 ',
#   'North America',
#   '2',
#   '399',
#   '0',
#   '',
#   '',
#   '494,535'],
#  ['118',
#   'Trinidad and Tobago',
#   '186,685',
#   '',
#   '4,297                                ',
#   '',
#   '182,182',
#   '',
#   '206',
#   '8',
#   '132,722',
#   '3,055',
#   '882,325',
#   '627,282',
#   '1,406,585 ',
#   'North America',
#   '8',
#   '327',
#   '2',
#   '',
#   '',
#   '146'],
#  ['119',
#   'Maldives',
#   '185,702',
#   '',
#   '311                                ',
#   '',
#   '163,687',
#   '',
#   '21,704',
#   '25',
#   '343,266',
#   '575',
#   '2,213,831',
#   '4,092,223',
#   '540,985 ',
#   'Asia',
#   '3',
#   '1,740',
#   '0',
#   '',
#   '',
#   '40,119'],
#  ['120',
#   'Ghana',
#   '171,065',
#   '',
#   '1,461                                ',
#   '',
#   '169,586',
#   '',
#   '18',
#   '2',
#   '5,281',
#   '45',
#   '2,525,056',
#   '77,945',
#   '32,395,450 ',
#   'Africa',
#   '189',
#   '22,173',
#   '13',
#   '',
#   '',
#   '0.6'],
#  ['121',
#   'Namibia',
#   '170,295',
#   '',
#   '4,082                                ',
#   '',
#   '165,961',
#   '',
#   '252',
#   '',
#   '64,656',
#   '1,550',
#   '1,062,663',
#   '403,460',
#   '2,633,874 ',
#   'Africa',
#   '15',
#   '645',
#   '2',
#   '',
#   '',
#   '96'],
#  ['122',
#   'Uganda',
#   '170,209',
#   '',
#   '3,630                                ',
#   '',
#   '100,431',
#   '',
#   '66,148',
#   '3',
#   '3,514',
#   '75',
#   '3,012,408',
#   '62,198',
#   '48,432,863 ',
#   'Africa',
#   '285',
#   '13,342',
#   '16',
#   '',
#   '',
#   '1,366'],
#  ['123',
#   'Jamaica',
#   '152,827',
#   '',
#   '3,465                                ',
#   '',
#   '101,996',
#   '',
#   '47,366',
#   '',
#   '51,197',
#   '1,161',
#   '1,183,986',
#   '396,633',
#   '2,985,094 ',
#   'North America',
#   '20',
#   '861',
#   '3',
#   '',
#   '',
#   '15,868'],
#  ['124',
#   'Cambodia',
#   '138,642',
#   '+4',
#   '3,056                                ',
#   '',
#   '135,565',
#   '+9',
#   '21',
#   '',
#   '8,075',
#   '178',
#   '3,091,420',
#   '180,062',
#   '17,168,639 ',
#   'Asia',
#   '124',
#   '5,618',
#   '6',
#   '0.2',
#   '',
#   '1'],
#  ['125',
#   'Rwanda',
#   '133,063',
#   '',
#   '1,468                                ',
#   '',
#   '131,112',
#   '',
#   '483',
#   '',
#   '9,784',
#   '108',
#   '5,959,042',
#   '438,150',
#   '13,600,464 ',
#   'Africa',
#   '102',
#   '9,265',
#   '2',
#   '',
#   '',
#   '36'],
#  ['126',
#   'Cameroon',
#   '123,993',
#   '',
#   '1,965                                ',
#   '',
#   '118,616',
#   '',
#   '3,412',
#   '13',
#   '4,442',
#   '70',
#   '1,751,774',
#   '62,762',
#   '27,911,548 ',
#   'Africa',
#   '225',
#   '14,204',
#   '16',
#   '',
#   '',
#   '122'],
#  ['127',
#   'Malta',
#   '116,704',
#   '',
#   '822                                ',
#   '',
#   '115,068',
#   '',
#   '814',
#   '4',
#   '262,827',
#   '1,851',
#   '2,103,127',
#   '4,736,420',
#   '444,033 ',
#   'Europe',
#   '4',
#   '540',
#   '0',
#   '',
#   '',
#   '1,833'],
#  ['128',
#   'Barbados',
#   '105,905',
#   '',
#   '569                                ',
#   '',
#   '105,314',
#   '',
#   '22',
#   '',
#   '367,696',
#   '1,976',
#   '788,414',
#   '2,737,330',
#   '288,023 ',
#   'North America',
#   '3',
#   '506',
#   '0',
#   '',
#   '',
#   '76'],
#  ['129',
#   'Angola',
#   '105,095',
#   '',
#   '1,930                                ',
#   '',
#   '103,050',
#   '',
#   '115',
#   '',
#   '3,000',
#   '55',
#   '1,499,795',
#   '42,818',
#   '35,027,343 ',
#   'Africa',
#   '333',
#   '18,149',
#   '23',
#   '',
#   '',
#   '3'],
#  ['130',
#   'Channel Islands',
#   '100,373',
#   '',
#   '219                                ',
#   '',
#   '99,304',
#   '',
#   '850',
#   '',
#   '568,805',
#   '1,241',
#   '1,252,808',
#   '7,099,551',
#   '176,463 ',
#   'Europe',
#   '2',
#   '806',
#   '0',
#   '',
#   '',
#   '4,817'],
#  ['131',
#   'French Guiana',
#   '97,946',
#   '',
#   '415                                ',
#   '',
#   '11,254',
#   '',
#   '86,277',
#   '6',
#   '311,762',
#   '1,321',
#   '651,257',
#   '2,072,951',
#   '314,169 ',
#   'South America',
#   '3',
#   '757',
#   '0',
#   '',
#   '',
#   '274,620'],
#  ['132',
#   'DRC',
#   '95,173',
#   '',
#   '1,462                                ',
#   '',
#   '84,159',
#   '',
#   '9,552',
#   '',
#   '999',
#   '15',
#   '846,704',
#   '8,890',
#   '95,240,792 ',
#   'Africa',
#   '1,001',
#   '65,144',
#   '112',
#   '',
#   '',
#   '100'],
#  ['133',
#   'Senegal',
#   '88,900',
#   '',
#   '1,968                                ',
#   '',
#   '86,915',
#   '',
#   '17',
#   '',
#   '5,036',
#   '111',
#   '1,146,543',
#   '64,946',
#   '17,653,671 ',
#   'Africa',
#   '199',
#   '8,970',
#   '15',
#   '',
#   '',
#   '1.0'],
#  ['134',
#   'Malawi',
#   '88,220',
#   '',
#   '2,685                                ',
#   '',
#   '85,065',
#   '',
#   '470',
#   '67',
#   '4,371',
#   '133',
#   '624,784',
#   '30,959',
#   '20,180,839 ',
#   'Africa',
#   '229',
#   '7,516',
#   '32',
#   '',
#   '',
#   '23'],
#  ['135',
#   'Ivory Coast',
#   '87,960',
#   '',
#   '833                                ',
#   '',
#   '87,116',
#   '',
#   '11',
#   '',
#   '3,171',
#   '30',
#   '1,666,268',
#   '60,062',
#   '27,742,298 ',
#   'Africa',
#   '315',
#   '33,304',
#   '17',
#   '',
#   '',
#   '0.4'],
#  ['136',
#   'Suriname',
#   '82,020',
#   '',
#   '1,398                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '137,426',
#   '2,342',
#   '239,603',
#   '401,459',
#   '596,831 ',
#   'South America',
#   '7',
#   '427',
#   '2',
#   '',
#   '',
#   '51,802'],
#  ['137',
#   'New Caledonia',
#   '79,724',
#   '',
#   '314                                ',
#   '',
#   '79,234',
#   '',
#   '176',
#   '9',
#   '274,046',
#   '1,079',
#   '98,964',
#   '340,182',
#   '290,915 ',
#   'Australia/Oceania',
#   '4',
#   '926',
#   '3',
#   '',
#   '',
#   '605'],
#  ['138',
#   'French Polynesia',
#   '77,957',
#   '',
#   '649                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '274,338',
#   '2,284',
#   '',
#   '',
#   '284,164 ',
#   'Australia/Oceania',
#   '4',
#   '438',
#   '',
#   '',
#   '',
#   '154,164'],
#  ['139',
#   'Eswatini',
#   '74,053',
#   '',
#   '1,422                                ',
#   '',
#   '72,603',
#   '',
#   '28',
#   '',
#   '62,502',
#   '1,200',
#   '1,048,081',
#   '884,593',
#   '1,184,817 ',
#   'Africa',
#   '16',
#   '833',
#   '1',
#   '',
#   '',
#   '24'],
#  ['140',
#   'Guyana',
#   '72,538',
#   '',
#   '1,291                                ',
#   '',
#   '70,903',
#   '',
#   '344',
#   '',
#   '91,353',
#   '1,626',
#   '712,962',
#   '897,886',
#   '794,045 ',
#   'South America',
#   '11',
#   '615',
#   '1',
#   '',
#   '',
#   '433'],
#  ['141',
#   'Belize',
#   '70,397',
#   '',
#   '688                                ',
#   '',
#   '69,605',
#   '',
#   '104',
#   '6',
#   '170,788',
#   '1,669',
#   '576,016',
#   '1,397,453',
#   '412,190 ',
#   'North America',
#   '6',
#   '599',
#   '1',
#   '',
#   '',
#   '252'],
#  ['142',
#   'Fiji',
#   '68,771',
#   '',
#   '883                                ',
#   '',
#   '66,730',
#   '',
#   '1,158',
#   '',
#   '75,617',
#   '971',
#   '666,782',
#   '733,158',
#   '909,466 ',
#   'Australia/Oceania',
#   '13',
#   '1,030',
#   '1',
#   '',
#   '',
#   '1,273'],
#  ['143',
#   'Madagascar',
#   '67,760',
#   '',
#   '1,418                                ',
#   '',
#   '66,316',
#   '',
#   '26',
#   '',
#   '2,322',
#   '49',
#   '523,108',
#   '17,928',
#   '29,178,077 ',
#   'Africa',
#   '431',
#   '20,577',
#   '56',
#   '',
#   '',
#   '0.9'],
#  ['144',
#   'Sudan',
#   '63,702',
#   '',
#   '4,995                                ',
#   '',
#   '58,275',
#   '',
#   '432',
#   '',
#   '1,385',
#   '109',
#   '562,941',
#   '12,240',
#   '45,992,020 ',
#   'Africa',
#   '722',
#   '9,208',
#   '82',
#   '',
#   '',
#   '9'],
#  ['145',
#   'Mauritania',
#   '63,429',
#   '',
#   '997                                ',
#   '',
#   '62,423',
#   '',
#   '9',
#   '',
#   '12,939',
#   '203',
#   '1,009,957',
#   '206,030',
#   '4,901,981 ',
#   'Africa',
#   '77',
#   '4,917',
#   '5',
#   '',
#   '',
#   '2'],
#  ['146',
#   'Cabo Verde',
#   '63,214',
#   '',
#   '412                                ',
#   '',
#   '62,738',
#   '',
#   '64',
#   '23',
#   '111,355',
#   '726',
#   '401,622',
#   '707,482',
#   '567,678 ',
#   'Africa',
#   '9',
#   '1,378',
#   '1',
#   '',
#   '',
#   '113'],
#  ['147',
#   'Bhutan',
#   '62,551',
#   '',
#   '21                                ',
#   '',
#   '61,564',
#   '',
#   '966',
#   '',
#   '79,385',
#   '27',
#   '2,303,734',
#   '2,923,739',
#   '787,941 ',
#   'Asia',
#   '13',
#   '37,521',
#   '0',
#   '',
#   '',
#   '1,226'],
#  ['148',
#   'Syria',
#   '57,423',
#   '',
#   '3,163                                ',
#   '',
#   '54,260',
#   '',
#   '0',
#   '',
#   '2,965',
#   '163',
#   '146,269',
#   '7,553',
#   '19,364,809 ',
#   'Asia',
#   '337',
#   '6,122',
#   '132',
#   '',
#   '',
#   ''],
#  ['149',
#   'Burundi',
#   '52,162',
#   '',
#   '38                                ',
#   '',
#   '51,393',
#   '',
#   '731',
#   '',
#   '4,132',
#   '3',
#   '345,742',
#   '27,386',
#   '12,624,840 ',
#   'Africa',
#   '242',
#   '332,233',
#   '37',
#   '',
#   '',
#   '58'],
#  ['150',
#   'Seychelles',
#   '50,355',
#   '',
#   '172                                ',
#   '',
#   '50,026',
#   '',
#   '157',
#   '',
#   '506,457',
#   '1,730',
#   '',
#   '',
#   '99,426 ',
#   'Africa',
#   '2',
#   '578',
#   '',
#   '',
#   '',
#   '1,579'],
#  ['151',
#   'Gabon',
#   '48,980',
#   '',
#   '306                                ',
#   '',
#   '48,668',
#   '',
#   '6',
#   '',
#   '21,008',
#   '131',
#   '1,621,909',
#   '695,641',
#   '2,331,533 ',
#   'Africa',
#   '48',
#   '7,619',
#   '1',
#   '',
#   '',
#   '3'],
#  ['152',
#   'Andorra',
#   '47,781',
#   '',
#   '165                                ',
#   '',
#   '47,563',
#   '',
#   '53',
#   '14',
#   '616,824',
#   '2,130',
#   '249,838',
#   '3,225,256',
#   '77,463 ',
#   'Europe',
#   '2',
#   '469',
#   '0',
#   '',
#   '',
#   '684'],
#  ['153',
#   'Papua New Guinea',
#   '46,663',
#   '',
#   '669                                ',
#   '',
#   '43,982',
#   '',
#   '2,012',
#   '7',
#   '5,022',
#   '72',
#   '249,149',
#   '26,813',
#   '9,292,169 ',
#   'Australia/Oceania',
#   '199',
#   '13,890',
#   '37',
#   '',
#   '',
#   '217'],
#  ['154',
#   'Curaçao',
#   '45,986',
#   '',
#   '295                                ',
#   '',
#   '44,720',
#   '',
#   '971',
#   '3',
#   '277,812',
#   '1,782',
#   '496,693',
#   '3,000,640',
#   '165,529 ',
#   'North America',
#   '4',
#   '561',
#   '0',
#   '',
#   '',
#   '5,866'],
#  ['155',
#   'Aruba',
#   '43,860',
#   '',
#   '236                                ',
#   '',
#   '42,438',
#   '',
#   '1,186',
#   '2',
#   '407,587',
#   '2,193',
#   '177,885',
#   '1,653,068',
#   '107,609 ',
#   'North America',
#   '2',
#   '456',
#   '1',
#   '',
#   '',
#   '11,021'],
#  ['156',
#   'Tanzania',
#   '42,396',
#   '',
#   '845                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '670',
#   '13',
#   '',
#   '',
#   '63,298,550 ',
#   'Africa',
#   '1,493',
#   '74,910',
#   '',
#   '',
#   '',
#   '654'],
#  ['157',
#   'Mayotte',
#   '42,002',
#   '',
#   '188                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '146,727',
#   '657',
#   '176,919',
#   '618,038',
#   '286,259 ',
#   'Africa',
#   '7',
#   '1,523',
#   '2',
#   '',
#   '',
#   '135,716'],
#  ['158',
#   'Mauritius',
#   '41,541',
#   '',
#   '1,041                                ',
#   '',
#   '39,807',
#   '',
#   '693',
#   '',
#   '32,588',
#   '817',
#   '358,675',
#   '281,374',
#   '1,274,727 ',
#   'Africa',
#   '31',
#   '1,225',
#   '4',
#   '',
#   '',
#   '544'],
#  ['159',
#   'Togo',
#   '39,349',
#   '',
#   '290                                ',
#   '',
#   '39,051',
#   '',
#   '8',
#   '',
#   '4,533',
#   '33',
#   '805,295',
#   '92,767',
#   '8,680,837 ',
#   'Africa',
#   '221',
#   '29,934',
#   '11',
#   '',
#   '',
#   '0.9'],
#  ['160',
#   'Guinea',
#   '38,210',
#   '',
#   '466                                ',
#   '',
#   '37,292',
#   '',
#   '452',
#   '8',
#   '2,756',
#   '34',
#   '660,107',
#   '47,607',
#   '13,865,691 ',
#   'Africa',
#   '363',
#   '29,755',
#   '21',
#   '',
#   '',
#   '33'],
#  ['161',
#   'Isle of Man',
#   '38,008',
#   '',
#   '116                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '443,335',
#   '1,353',
#   '150,753',
#   '1,758,422',
#   '85,732 ',
#   'Europe',
#   '2',
#   '739',
#   '1',
#   '',
#   '',
#   '129,450'],
#  ['162',
#   'Bahamas',
#   '37,491',
#   '',
#   '833                                ',
#   '',
#   '36,366',
#   '',
#   '292',
#   '1',
#   '93,607',
#   '2,080',
#   '257,839',
#   '643,767',
#   '400,516 ',
#   'North America',
#   '11',
#   '481',
#   '2',
#   '',
#   '',
#   '729'],
#  ['163',
#   'Lesotho',
#   '34,790',
#   '',
#   '723                                ',
#   '',
#   '25,980',
#   '',
#   '8,087',
#   '',
#   '15,990',
#   '332',
#   '431,221',
#   '198,199',
#   '2,175,699 ',
#   'Africa',
#   '63',
#   '3,009',
#   '5',
#   '',
#   '',
#   '3,717'],
#  ['164',
#   'Faeroe Islands',
#   '34,658',
#   '',
#   '28                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '5',
#   '703,959',
#   '569',
#   '778,000',
#   '15,802,409',
#   '49,233 ',
#   'Europe',
#   '1',
#   '1,758',
#   '0',
#   '',
#   '',
#   '547,133'],
#  ['165',
#   'Haiti',
#   '33,969',
#   '',
#   '860                                ',
#   '',
#   '32,977',
#   '',
#   '132',
#   '',
#   '2,908',
#   '74',
#   '132,422',
#   '11,337',
#   '11,680,283 ',
#   'North America',
#   '344',
#   '13,582',
#   '88',
#   '',
#   '',
#   '11'],
#  ['166',
#   'Mali',
#   '32,771',
#   '',
#   '743                                ',
#   '',
#   '31,951',
#   '',
#   '77',
#   '',
#   '1,526',
#   '35',
#   '785,528',
#   '36,581',
#   '21,473,764 ',
#   'Africa',
#   '655',
#   '28,901',
#   '27',
#   '',
#   '',
#   '4'],
#  ['167',
#   'Cayman Islands',
#   '31,472',
#   '',
#   '37                                ',
#   '',
#   '8,553',
#   '',
#   '22,882',
#   '1',
#   '467,797',
#   '550',
#   '222,773',
#   '3,311,280',
#   '67,277 ',
#   'North America',
#   '2',
#   '1,818',
#   '0',
#   '',
#   '',
#   '340,116'],
#  ['168',
#   'Saint Lucia',
#   '29,759',
#   '',
#   '409                                ',
#   '',
#   '29,095',
#   '',
#   '255',
#   '',
#   '160,761',
#   '2,209',
#   '210,983',
#   '1,139,752',
#   '185,113 ',
#   'North America',
#   '6',
#   '453',
#   '1',
#   '',
#   '',
#   '1,378'],
#  ['169',
#   'Benin',
#   '27,982',
#   '',
#   '163                                ',
#   '',
#   '27,817',
#   '',
#   '2',
#   '',
#   '2,189',
#   '13',
#   '604,310',
#   '47,268',
#   '12,784,726 ',
#   'Africa',
#   '457',
#   '78,434',
#   '21',
#   '',
#   '',
#   '0.2'],
#  ['170',
#   'Somalia',
#   '27,310',
#   '',
#   '1,361                                ',
#   '',
#   '13,182',
#   '',
#   '12,767',
#   '',
#   '1,622',
#   '81',
#   '400,466',
#   '23,778',
#   '16,841,795 ',
#   'Africa',
#   '617',
#   '12,375',
#   '42',
#   '',
#   '',
#   '758'],
#  ['171',
#   'Congo',
#   '25,375',
#   '',
#   '386                                ',
#   '',
#   '24,006',
#   '',
#   '983',
#   '',
#   '4,377',
#   '67',
#   '347,815',
#   '59,991',
#   '5,797,805 ',
#   'Africa',
#   '228',
#   '15,020',
#   '17',
#   '',
#   '',
#   '170'],
#  ['172',
#   'Solomon Islands',
#   '24,575',
#   '',
#   '153                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '1',
#   '34,077',
#   '212',
#   '',
#   '',
#   '721,159 ',
#   'Australia/Oceania',
#   '29',
#   '4,713',
#   '',
#   '',
#   '',
#   '11,183'],
#  ['173',
#   'Timor-Leste',
#   '23,403',
#   '',
#   '138                                ',
#   '',
#   '23,102',
#   '',
#   '163',
#   '',
#   '17,090',
#   '101',
#   '278,529',
#   '203,391',
#   '1,369,429 ',
#   'Asia',
#   '59',
#   '9,923',
#   '5',
#   '',
#   '',
#   '119'],
#  ['174',
#   'San Marino',
#   '23,290',
#   '',
#   '121                                ',
#   '',
#   '23,034',
#   '',
#   '135',
#   '4',
#   '683,292',
#   '3,550',
#   '157,634',
#   '4,624,732',
#   '34,085 ',
#   'Europe',
#   '1',
#   '282',
#   '0',
#   '',
#   '',
#   '3,961'],
#  ['175',
#   'Micronesia',
#   '22,247',
#   '',
#   '58                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '1',
#   '189,354',
#   '494',
#   '54,967',
#   '467,848',
#   '117,489 ',
#   'Australia/Oceania',
#   '5',
#   '2,026',
#   '2',
#   '',
#   '',
#   '187,379'],
#  ['176',
#   'Burkina Faso',
#   '22,023',
#   '',
#   '395                                ',
#   '',
#   '21,596',
#   '',
#   '32',
#   '',
#   '996',
#   '18',
#   '248,995',
#   '11,265',
#   '22,102,838 ',
#   'Africa',
#   '1,004',
#   '55,957',
#   '89',
#   '',
#   '',
#   '1'],
#  ['177',
#   'Liechtenstein',
#   '21,305',
#   '',
#   '88                                ',
#   '',
#   '21,186',
#   '',
#   '31',
#   '',
#   '555,006',
#   '2,292',
#   '112,457',
#   '2,929,559',
#   '38,387 ',
#   'Europe',
#   '2',
#   '436',
#   '0',
#   '',
#   '',
#   '808'],
#  ['178',
#   'Gibraltar',
#   '20,342',
#   '',
#   '111                                ',
#   '',
#   '16,579',
#   '',
#   '3,652',
#   '',
#   '603,549',
#   '3,293',
#   '534,283',
#   '15,852,213',
#   '33,704 ',
#   'Europe',
#   '2',
#   '304',
#   '0',
#   '',
#   '',
#   '108,355'],
#  ['179',
#   'Grenada',
#   '19,680',
#   '',
#   '238                                ',
#   '',
#   '19,358',
#   '',
#   '84',
#   '4',
#   '173,430',
#   '2,097',
#   '182,981',
#   '1,612,523',
#   '113,475 ',
#   'North America',
#   '6',
#   '477',
#   '1',
#   '',
#   '',
#   '740'],
#  ['180',
#   'Bermuda',
#   '18,684',
#   '',
#   '154                                ',
#   '',
#   '18,465',
#   '',
#   '65',
#   '',
#   '301,652',
#   '2,486',
#   '1,022,846',
#   '16,513,764',
#   '61,939 ',
#   'North America',
#   '3',
#   '402',
#   '0',
#   '',
#   '',
#   '1,049'],
#  ['181',
#   'Nicaragua',
#   '18,491',
#   '',
#   '225                                ',
#   '',
#   '4,225',
#   '',
#   '14,041',
#   '',
#   '2,728',
#   '33',
#   '',
#   '',
#   '6,779,100 ',
#   'North America',
#   '367',
#   '30,129',
#   '',
#   '',
#   '',
#   '2,071'],
#  ['182',
#   'South Sudan',
#   '18,368',
#   '',
#   '138                                ',
#   '',
#   '18,115',
#   '',
#   '115',
#   '1',
#   '1,581',
#   '12',
#   '410,280',
#   '35,313',
#   '11,618,511 ',
#   'Africa',
#   '633',
#   '84,192',
#   '28',
#   '',
#   '',
#   '10'],
#  ['183',
#   'Tajikistan',
#   '17,786',
#   '',
#   '125                                ',
#   '',
#   '17,264',
#   '',
#   '397',
#   '',
#   '1,786',
#   '13',
#   '',
#   '',
#   '9,957,464 ',
#   'Asia',
#   '560',
#   '79,660',
#   '',
#   '',
#   '',
#   '40'],
#  ['184',
#   'Equatorial Guinea',
#   '17,186',
#   '',
#   '183                                ',
#   '',
#   '16,880',
#   '',
#   '123',
#   '5',
#   '11,483',
#   '122',
#   '365,697',
#   '244,342',
#   '1,496,662 ',
#   'Africa',
#   '87',
#   '8,178',
#   '4',
#   '',
#   '',
#   '82'],
#  ['185',
#   'Tonga',
#   '16,487',
#   '',
#   '12                                ',
#   '',
#   '15,638',
#   '',
#   '837',
#   '',
#   '153,013',
#   '111',
#   '535,009',
#   '4,965,327',
#   '107,749 ',
#   'Australia/Oceania',
#   '7',
#   '8,979',
#   '0',
#   '',
#   '',
#   '7,768'],
#  ['186',
#   'Monaco',
#   '16,004',
#   '',
#   '65                                ',
#   '',
#   '15,915',
#   '',
#   '24',
#   '4',
#   '402,282',
#   '1,634',
#   '78,646',
#   '1,976,875',
#   '39,783 ',
#   'Europe',
#   '2',
#   '612',
#   '1',
#   '',
#   '',
#   '603'],
#  ['187',
#   'Samoa',
#   '15,991',
#   '',
#   '29                                ',
#   '',
#   '1,605',
#   '',
#   '14,357',
#   '4',
#   '79,070',
#   '143',
#   '187,397',
#   '926,612',
#   '202,239 ',
#   'Australia/Oceania',
#   '13',
#   '6,974',
#   '1',
#   '',
#   '',
#   '70,990'],
#  ['188',
#   'Dominica',
#   '15,760',
#   '',
#   '74                                ',
#   '',
#   '15,673',
#   '',
#   '13',
#   '',
#   '217,848',
#   '1,023',
#   '229,344',
#   '3,170,187',
#   '72,344 ',
#   'North America',
#   '5',
#   '978',
#   '0',
#   '',
#   '',
#   '180'],
#  ['189',
#   'Djibouti',
#   '15,690',
#   '',
#   '189                                ',
#   '',
#   '15,427',
#   '',
#   '74',
#   '',
#   '15,441',
#   '186',
#   '305,941',
#   '301,094',
#   '1,016,097 ',
#   'Africa',
#   '65',
#   '5,376',
#   '3',
#   '',
#   '',
#   '73'],
#  ['190',
#   'Marshall Islands',
#   '15,554',
#   '',
#   '17                                ',
#   '',
#   '15,528',
#   '',
#   '9',
#   '',
#   '258,987',
#   '283',
#   '',
#   '',
#   '60,057 ',
#   'Australia/Oceania',
#   '4',
#   '3,533',
#   '',
#   '',
#   '',
#   '150'],
#  ['191',
#   'CAR',
#   '15,351',
#   '',
#   '113                                ',
#   '',
#   '14,615',
#   '',
#   '623',
#   '2',
#   '3,060',
#   '23',
#   '81,294',
#   '16,205',
#   '5,016,678 ',
#   'Africa',
#   '327',
#   '44,395',
#   '62',
#   '',
#   '',
#   '124'],
#  ['192',
#   'Gambia',
#   '12,586',
#   '',
#   '372                                ',
#   '',
#   '12,189',
#   '',
#   '25',
#   '',
#   '4,919',
#   '145',
#   '155,686',
#   '60,851',
#   '2,558,482 ',
#   'Africa',
#   '203',
#   '6,878',
#   '16',
#   '',
#   '',
#   '10'],
#  ['193',
#   'Saint Martin',
#   '12,222',
#   '',
#   '63                                ',
#   '',
#   '1,399',
#   '',
#   '10,760',
#   '7',
#   '307,626',
#   '1,586',
#   '112,382',
#   '2,828,643',
#   '39,730 ',
#   'North America',
#   '3',
#   '631',
#   '0',
#   '',
#   '',
#   '270,828'],
#  ['194',
#   'Vanuatu',
#   '12,014',
#   '',
#   '14                                ',
#   '',
#   '11,976',
#   '',
#   '24',
#   '',
#   '37,330',
#   '44',
#   '24,976',
#   '77,606',
#   '321,832 ',
#   'Australia/Oceania',
#   '27',
#   '22,988',
#   '13',
#   '',
#   '',
#   '75'],
#  ['195',
#   'Greenland',
#   '11,971',
#   '',
#   '21                                ',
#   '',
#   '2,761',
#   '',
#   '9,189',
#   '4',
#   '210,117',
#   '369',
#   '164,926',
#   '2,894,810',
#   '56,973 ',
#   'North America',
#   '5',
#   '2,713',
#   '0',
#   '',
#   '',
#   '161,287'],
#  ['196',
#   'Yemen',
#   '11,945',
#   '',
#   '2,159                                ',
#   '',
#   '9,124',
#   '',
#   '662',
#   '23',
#   '383',
#   '69',
#   '329,592',
#   '10,579',
#   '31,154,867 ',
#   'Asia',
#   '2,608',
#   '14,430',
#   '95',
#   '',
#   '',
#   '21'],
#  ['197',
#   'Caribbean Netherlands',
#   '11,635',
#   '',
#   '38                                ',
#   '',
#   '10,476',
#   '',
#   '1,121',
#   '',
#   '436,635',
#   '1,426',
#   '30,126',
#   '1,130,559',
#   '26,647 ',
#   'North America',
#   '2',
#   '701',
#   '1',
#   '',
#   '',
#   '42,069'],
#  ['198',
#   'Sint Maarten',
#   '10,998',
#   '',
#   '89                                ',
#   '',
#   '10,905',
#   '',
#   '4',
#   '',
#   '250,148',
#   '2,024',
#   '62,056',
#   '1,411,454',
#   '43,966 ',
#   'North America',
#   '4',
#   '494',
#   '1',
#   '',
#   '',
#   '91'],
#  ['199',
#   'Eritrea',
#   '10,189',
#   '',
#   '103                                ',
#   '',
#   '10,086',
#   '',
#   '0',
#   '',
#   '2,782',
#   '28',
#   '23,693',
#   '6,470',
#   '3,662,244 ',
#   'Africa',
#   '359',
#   '35,556',
#   '155',
#   '',
#   '',
#   ''],
#  ['200',
#   'Niger',
#   '9,931',
#   '',
#   '312                                ',
#   '',
#   '8,890',
#   '',
#   '729',
#   '1',
#   '381',
#   '12',
#   '254,538',
#   '9,759',
#   '26,083,660 ',
#   'Africa',
#   '2,626',
#   '83,601',
#   '102',
#   '',
#   '',
#   '28'],
#  ['201',
#   'St. Vincent Grenadines',
#   '9,552',
#   '',
#   '120                                ',
#   '',
#   '9,409',
#   '',
#   '23',
#   '',
#   '85,629',
#   '1,076',
#   '113,169',
#   '1,014,505',
#   '111,551 ',
#   'North America',
#   '12',
#   '930',
#   '1',
#   '',
#   '',
#   '206'],
#  ['202',
#   'Antigua and Barbuda',
#   '9,106',
#   '',
#   '146                                ',
#   '',
#   '8,954',
#   '',
#   '6',
#   '1',
#   '91,509',
#   '1,467',
#   '18,901',
#   '189,943',
#   '99,509 ',
#   'North America',
#   '11',
#   '682',
#   '5',
#   '',
#   '',
#   '60'],
#  ['203',
#   'Comoros',
#   '8,986',
#   '',
#   '161                                ',
#   '',
#   '8,822',
#   '',
#   '3',
#   '',
#   '9,903',
#   '177',
#   '',
#   '',
#   '907,419 ',
#   'Africa',
#   '101',
#   '5,636',
#   '',
#   '',
#   '',
#   '3'],
#  ['204',
#   'Guinea-Bissau',
#   '8,947',
#   '',
#   '176                                ',
#   '',
#   '8,656',
#   '',
#   '115',
#   '6',
#   '4,336',
#   '85',
#   '145,231',
#   '70,385',
#   '2,063,367 ',
#   'Africa',
#   '231',
#   '11,724',
#   '14',
#   '',
#   '',
#   '56'],
#  ['205',
#   'Liberia',
#   '8,043',
#   '',
#   '294                                ',
#   '',
#   '7,741',
#   '',
#   '8',
#   '2',
#   '1,516',
#   '55',
#   '139,824',
#   '26,356',
#   '5,305,117 ',
#   'Africa',
#   '660',
#   '18,045',
#   '38',
#   '',
#   '',
#   '2'],
#  ['206',
#   'Sierra Leone',
#   '7,760',
#   '',
#   '126                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '934',
#   '15',
#   '259,958',
#   '31,296',
#   '8,306,436 ',
#   'Africa',
#   '1,070',
#   '65,924',
#   '32',
#   '',
#   '',
#   '330'],
#  ['207',
#   'Chad',
#   '7,651',
#   '',
#   '194                                ',
#   '',
#   '4,874',
#   '',
#   '2,583',
#   '',
#   '439',
#   '11',
#   '191,341',
#   '10,988',
#   '17,413,580 ',
#   'Africa',
#   '2,276',
#   '89,761',
#   '91',
#   '',
#   '',
#   '148'],
#  ['208',
#   'British Virgin Islands',
#   '7,305',
#   '',
#   '64                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '238,757',
#   '2,092',
#   '107,339',
#   '3,508,269',
#   '30,596 ',
#   'North America',
#   '4',
#   '478',
#   '0',
#   '',
#   '',
#   '392'],
#  ['209',
#   'Cook Islands',
#   '6,860',
#   '',
#   '1                                ',
#   '',
#   '6,782',
#   '',
#   '77',
#   '',
#   '390,416',
#   '57',
#   '19,690',
#   '1,120,596',
#   '17,571 ',
#   'Australia/Oceania',
#   '3',
#   '17,571',
#   '1',
#   '',
#   '',
#   '4,382'],
#  ['210',
#   'Saint Kitts and Nevis',
#   '6,573',
#   '',
#   '46                                ',
#   '',
#   '6,521',
#   '',
#   '6',
#   '',
#   '122,014',
#   '854',
#   '126,848',
#   '2,354,662',
#   '53,871 ',
#   'North America',
#   '8',
#   '1,171',
#   '0',
#   '',
#   '',
#   '111'],
#  ['211',
#   'Turks and Caicos',
#   '6,479',
#   '',
#   '36                                ',
#   '',
#   '6,423',
#   '',
#   '20',
#   '4',
#   '163,031',
#   '906',
#   '611,527',
#   '15,387,811',
#   '39,741 ',
#   'North America',
#   '6',
#   '1,104',
#   '0',
#   '',
#   '',
#   '503'],
#  ['212',
#   'Sao Tome and Principe',
#   '6,279',
#   '',
#   '77                                ',
#   '',
#   '6,202',
#   '',
#   '0',
#   '',
#   '27,578',
#   '338',
#   '29,036',
#   '127,530',
#   '227,679 ',
#   'Africa',
#   '36',
#   '2,957',
#   '8',
#   '',
#   '',
#   ''],
#  ['213',
#   'Palau',
#   '5,976',
#   '',
#   '9                                ',
#   '',
#   '5,965',
#   '',
#   '2',
#   '1',
#   '327,757',
#   '494',
#   '68,587',
#   '3,761,696',
#   '18,233 ',
#   'Australia/Oceania',
#   '3',
#   '2,026',
#   '0',
#   '',
#   '',
#   '110'],
#  ['214',
#   'St. Barth',
#   '5,418',
#   '',
#   '6                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '544,796',
#   '603',
#   '78,646',
#   '7,908,095',
#   '9,945 ',
#   'North America',
#   '2',
#   '1,658',
#   '0',
#   '',
#   '',
#   '497,738'],
#  ['215',
#   'Nauru',
#   '4,621',
#   '',
#   '1                                ',
#   '',
#   '4,609',
#   '',
#   '11',
#   '',
#   '423,828',
#   '92',
#   '20,509',
#   '1,881,042',
#   '10,903 ',
#   'Australia/Oceania',
#   '2',
#   '10,903',
#   '1',
#   '',
#   '',
#   '1,009'],
#  ['216',
#   'Anguilla',
#   '3,904',
#   '',
#   '12                                ',
#   '',
#   '3,879',
#   '',
#   '13',
#   '4',
#   '256,336',
#   '788',
#   '51,382',
#   '3,373,736',
#   '15,230 ',
#   'North America',
#   '4',
#   '1,269',
#   '0',
#   '',
#   '',
#   '854'],
#  ['217',
#   'Kiribati',
#   '3,430',
#   '',
#   '13                                ',
#   '',
#   '2,703',
#   '',
#   '714',
#   '3',
#   '27,792',
#   '105',
#   '',
#   '',
#   '123,419 ',
#   'Australia/Oceania',
#   '36',
#   '9,494',
#   '',
#   '',
#   '',
#   '5,785'],
#  ['218',
#   'Wallis and Futuna',
#   '3,427',
#   '',
#   '7                                ',
#   '',
#   '438',
#   '',
#   '2,982',
#   '',
#   '312,056',
#   '637',
#   '20,508',
#   '1,867,419',
#   '10,982 ',
#   'Australia/Oceania',
#   '3',
#   '1,569',
#   '1',
#   '',
#   '',
#   '271,535'],
#  ['219',
#   'Macao',
#   '3,360',
#   '',
#   '91                                ',
#   '',
#   '3,047',
#   '',
#   '222',
#   '',
#   '5,034',
#   '136',
#   '7,850',
#   '11,760',
#   '667,490 ',
#   'Asia',
#   '199',
#   '7,335',
#   '85',
#   '',
#   '',
#   '333'],
#  ['220',
#   'Saint Pierre Miquelon',
#   '3,349',
#   '',
#   '2                                ',
#   '',
#   '2,449',
#   '',
#   '898',
#   '1',
#   '581,525',
#   '347',
#   '25,400',
#   '4,410,488',
#   '5,759 ',
#   'North America',
#   '2',
#   '2,880',
#   '0',
#   '',
#   '',
#   '155,930'],
#  ['221',
#   'Tuvalu',
#   '2,805',
#   '',
#   ' ',
#   '',
#   '',
#   '',
#   '2,805',
#   '',
#   '232,471',
#   '',
#   '',
#   '',
#   '12,066 ',
#   'Australia/Oceania',
#   '4',
#   '',
#   '',
#   '',
#   '',
#   '232,471'],
#  ['222',
#   'Falkland Islands',
#   '1,930',
#   '',
#   ' ',
#   '',
#   '1,930',
#   '',
#   '0',
#   '',
#   '545,352',
#   '',
#   '8,632',
#   '2,439,107',
#   '3,539 ',
#   'South America',
#   '2',
#   '',
#   '0',
#   '',
#   '',
#   ''],
#  ['223',
#   'Saint Helena',
#   '1,806',
#   '',
#   ' ',
#   '',
#   '2',
#   '',
#   '1,804',
#   '',
#   '295,339',
#   '',
#   '',
#   '',
#   '6,115 ',
#   'Africa',
#   '3',
#   '',
#   '',
#   '',
#   '',
#   '295,012'],
#  ['224',
#   'Montserrat',
#   '1,403',
#   '',
#   '8                                ',
#   '',
#   '1,376',
#   '',
#   '19',
#   '',
#   '282,578',
#   '1,611',
#   '17,762',
#   '3,577,442',
#   '4,965 ',
#   'North America',
#   '4',
#   '621',
#   '0',
#   '',
#   '',
#   '3,827'],
#  ['225',
#   'Diamond Princess',
#   '712',
#   '',
#   '13                                ',
#   '',
#   '699',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['226',
#   'Niue',
#   '644',
#   '',
#   ' ',
#   '',
#   '495',
#   '',
#   '149',
#   '',
#   '397,041',
#   '',
#   '',
#   '',
#   '1,622 ',
#   'Australia/Oceania',
#   '3',
#   '',
#   '',
#   '',
#   '',
#   '91,862'],
#  ['227',
#   'Vatican City',
#   '29',
#   '',
#   ' ',
#   '',
#   '29',
#   '',
#   '0',
#   '',
#   '36,295',
#   '',
#   '',
#   '',
#   '799 ',
#   'Europe',
#   '28',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['228',
#   'Western Sahara',
#   '10',
#   '',
#   '1                                ',
#   '',
#   '9',
#   '',
#   '0',
#   '',
#   '16',
#   '2',
#   '',
#   '',
#   '626,161 ',
#   'Africa',
#   '62,616',
#   '626,161',
#   '',
#   '',
#   '',
#   ''],
#  ['229',
#   'MS Zaandam',
#   '9',
#   '',
#   '2                                ',
#   '',
#   '7',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ' ',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['230',
#   'Tokelau',
#   '5',
#   '',
#   ' ',
#   '',
#   '',
#   '',
#   '5',
#   '',
#   '3,628',
#   '',
#   '',
#   '',
#   '1,378 ',
#   'Australia/Oceania',
#   '276',
#   '',
#   '',
#   '',
#   '',
#   '3,628'],
#  ['231',
#   'China',
#   '503,302',
#   '',
#   '5,272                                ',
#   '',
#   '379,053',
#   '',
#   '118,977',
#   '7,557',
#   '347',
#   '4',
#   '160,000,000',
#   '110,461',
#   '1,448,471,400                                ',
#   'Asia',
#   '2,878',
#   '274,748',
#   '9',
#   '',
#   '',
#   '82']]

# %%
# 1:10 ra 14

# %%
data=list(map(lambda x:x[1:10]+[x[14]],all_data))

# %%
data
# Out:
# [['USA',
#   '103,151,843',
#   '',
#   '1,121,725                                ',
#   '',
#   '100,061,532',
#   '',
#   '1,968,586',
#   '4,815',
#   '334,805,269 '],
#  ['India',
#   '44,681,523',
#   '',
#   '530,722                                ',
#   '',
#   '44,147,322',
#   '',
#   '3,479',
#   '698',
#   '1,406,631,776 '],
#  ['France',
#   '39,421,144',
#   '',
#   '163,105                                ',
#   '',
#   '38,862,625',
#   '',
#   '395,414',
#   '869',
#   '65,584,518 '],
#  ['Germany',
#   '37,562,191',
#   '',
#   '163,244                                ',
#   '',
#   '36,946,600',
#   '+40,900',
#   '452,347',
#   '1,281',
#   '83,883,596 '],
#  ['Brazil',
#   '36,560,497',
#   '',
#   '695,031                                ',
#   '',
#   '35,429,017',
#   '',
#   '436,449',
#   '8,318',
#   '215,353,593 '],
#  ['Japan',
#   '30,647,859',
#   '',
#   '60,411                                ',
#   '',
#   '21,271,832',
#   '',
#   '9,315,616',
#   '656',
#   '125,584,838 '],
#  ['S. Korea',
#   '29,654,090',
#   '+54,343',
#   '32,745                                ',
#   '+76',
#   '28,567,938',
#   '+66,005',
#   '1,053,407',
#   '540',
#   '51,329,899 '],
#  ['Italy',
#   '25,279,682',
#   '',
#   '185,417                                ',
#   '',
#   '24,688,083',
#   '',
#   '406,182',
#   '319',
#   '60,262,770 '],
#  ['UK',
#   '24,210,131',
#   '',
#   '201,028                                ',
#   '',
#   '23,895,374',
#   '+6,508',
#   '113,729',
#   '146',
#   '68,497,907 '],
#  ['Russia',
#   '21,832,768',
#   '',
#   '394,168                                ',
#   '',
#   '21,253,611',
#   '',
#   '184,989',
#   '2,300',
#   '145,805,947 '],
#  ['Turkey',
#   '17,042,722',
#   '',
#   '101,492                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '85,561,976 '],
#  ['Spain',
#   '13,693,478',
#   '',
#   '117,413                                ',
#   '',
#   '13,502,806',
#   '',
#   '73,259',
#   '231',
#   '46,719,142 '],
#  ['Vietnam',
#   '11,525,911',
#   '',
#   '43,186                                ',
#   '',
#   '10,611,547',
#   '',
#   '871,178',
#   '12',
#   '98,953,541 '],
#  ['Australia',
#   '11,211,305',
#   '+1,150',
#   '17,380                                ',
#   '+31',
#   '11,052,693',
#   '',
#   '141,232',
#   '109',
#   '26,068,792 '],
#  ['Argentina',
#   '10,004,679',
#   '',
#   '130,249                                ',
#   '',
#   '9,707,830',
#   '+8,843',
#   '166,600',
#   '402',
#   '46,010,234 '],
#  ['Taiwan',
#   '9,097,554',
#   '',
#   '15,608                                ',
#   '',
#   '8,609,056',
#   '',
#   '472,890',
#   '',
#   '23,888,595 '],
#  ['Netherlands',
#   '8,576,523',
#   '',
#   '22,989                                ',
#   '',
#   '8,528,649',
#   '',
#   '24,885',
#   '55',
#   '17,211,447 '],
#  ['Iran',
#   '7,562,169',
#   '',
#   '144,717                                ',
#   '',
#   '7,336,524',
#   '',
#   '80,928',
#   '167',
#   '86,022,837 '],
#  ['Mexico',
#   '7,284,502',
#   '',
#   '331,333                                ',
#   '',
#   '6,519,926',
#   '',
#   '433,243',
#   '4,798',
#   '131,562,772 '],
#  ['Indonesia',
#   '6,724,281',
#   '',
#   '160,697                                ',
#   '',
#   '6,555,664',
#   '',
#   '7,920',
#   '2,771',
#   '279,134,505 '],
#  ['Poland',
#   '6,371,866',
#   '',
#   '118,601                                ',
#   '',
#   '5,335,940',
#   '',
#   '917,325',
#   '1,192',
#   '37,739,785 '],
#  ['Colombia',
#   '6,349,971',
#   '',
#   '142,259                                ',
#   '',
#   '6,170,360',
#   '',
#   '37,352',
#   '342',
#   '51,512,762 '],
#  ['Austria',
#   '5,731,160',
#   '',
#   '21,517                                ',
#   '',
#   '5,680,255',
#   '',
#   '29,388',
#   '',
#   '9,066,710 '],
#  ['Portugal',
#   '5,557,941',
#   '',
#   '25,805                                ',
#   '',
#   '5,525,559',
#   '',
#   '6,577',
#   '61',
#   '10,140,570 '],
#  ['Greece',
#   '5,548,487',
#   '',
#   '34,779                                ',
#   '',
#   '5,513,708',
#   '',
#   '0',
#   '115',
#   '10,316,637 '],
#  ['Ukraine',
#   '5,361,352',
#   '',
#   '110,859                                ',
#   '',
#   '5,243,879',
#   '+623',
#   '6,614',
#   '',
#   '43,192,122 '],
#  ['Chile',
#   '5,071,034',
#   '',
#   '63,381                                ',
#   '',
#   '5,000,039',
#   '',
#   '7,614',
#   '113',
#   '19,250,195 '],
#  ['Malaysia',
#   '5,031,076',
#   '',
#   '36,892                                ',
#   '',
#   '4,982,772',
#   '',
#   '11,412',
#   '26',
#   '33,181,072 '],
#  ['DPRK',
#   '4,772,813',
#   '',
#   '74                                ',
#   '',
#   '4,772,739',
#   '',
#   '0',
#   '',
#   '25,990,679 '],
#  ['Israel',
#   '4,772,755',
#   '',
#   '12,101                                ',
#   '',
#   '4,750,133',
#   '',
#   '10,521',
#   '57',
#   '9,326,000 '],
#  ['Thailand',
#   '4,724,916',
#   '',
#   '33,727                                ',
#   '',
#   '4,690,108',
#   '',
#   '1,081',
#   '1,496',
#   '70,078,203 '],
#  ['Belgium',
#   '4,682,234',
#   '',
#   '33,395                                ',
#   '',
#   '4,619,471',
#   '+1,608',
#   '29,368',
#   '97',
#   '11,668,278 '],
#  ['Czechia',
#   '4,583,646',
#   '',
#   '42,220                                ',
#   '',
#   '4,536,834',
#   '',
#   '4,592',
#   '42',
#   '10,736,784 '],
#  ['Canada',
#   '4,508,275',
#   '',
#   '49,566                                ',
#   '',
#   '4,393,634',
#   '+2,361',
#   '65,075',
#   '99',
#   '38,388,419 '],
#  ['Peru',
#   '4,470,919',
#   '',
#   '218,414                                ',
#   '',
#   '4,232,661',
#   '',
#   '19,844',
#   '101',
#   '33,684,208 '],
#  ['Switzerland',
#   '4,382,359',
#   '',
#   '14,388                                ',
#   '',
#   '4,334,688',
#   '+1,242',
#   '33,283',
#   '63',
#   '8,773,637 '],
#  ['Philippines',
#   '4,068,425',
#   '',
#   '65,498                                ',
#   '',
#   '3,991,071',
#   '',
#   '11,856',
#   '162',
#   '112,508,994 '],
#  ['South Africa',
#   '4,050,288',
#   '',
#   '102,568                                ',
#   '',
#   '3,912,506',
#   '',
#   '35,214',
#   '192',
#   '60,756,135 '],
#  ['Romania',
#   '3,316,192',
#   '',
#   '67,460                                ',
#   '',
#   '3,241,020',
#   '+3,432',
#   '7,712',
#   '109',
#   '19,031,335 '],
#  ['Denmark',
#   '3,170,881',
#   '',
#   '7,941                                ',
#   '',
#   '3,156,224',
#   '',
#   '6,716',
#   '14',
#   '5,834,950 '],
#  ['Hong Kong',
#   '2,790,960',
#   '',
#   '12,481                                ',
#   '',
#   '2,155,003',
#   '',
#   '623,476',
#   '47',
#   '7,604,299 '],
#  ['Sweden',
#   '2,683,356',
#   '',
#   '22,110                                ',
#   '',
#   '2,623,235',
#   '+544',
#   '38,011',
#   '43',
#   '10,218,971 '],
#  ['Iraq',
#   '2,465,545',
#   '',
#   '25,375                                ',
#   '',
#   '2,439,497',
#   '',
#   '673',
#   '21',
#   '42,164,965 '],
#  ['Serbia',
#   '2,455,236',
#   '',
#   '17,574                                ',
#   '',
#   '2,421,479',
#   '',
#   '16,183',
#   '23',
#   '8,653,016 '],
#  ['Singapore',
#   '2,209,511',
#   '',
#   '1,714                                ',
#   '',
#   '2,135,949',
#   '',
#   '71,848',
#   '2',
#   '5,943,546 '],
#  ['Hungary',
#   '2,188,737',
#   '',
#   '48,546                                ',
#   '',
#   '2,127,121',
#   '',
#   '13,070',
#   '16',
#   '9,606,259 '],
#  ['New Zealand',
#   '2,138,754',
#   '',
#   '3,621                                ',
#   '',
#   '2,114,718',
#   '',
#   '20,415',
#   '',
#   '4,898,203 '],
#  ['Bangladesh',
#   '2,037,305',
#   '',
#   '29,440                                ',
#   '',
#   '1,988,846',
#   '',
#   '19,019',
#   '1,331',
#   '167,885,689 '],
#  ['Slovakia',
#   '1,859,788',
#   '',
#   '20,855                                ',
#   '',
#   '1,837,892',
#   '',
#   '1,041',
#   '28',
#   '5,460,193 '],
#  ['Georgia',
#   '1,809,359',
#   '',
#   '16,899                                ',
#   '',
#   '1,776,548',
#   '',
#   '15,912',
#   '',
#   '3,968,738 '],
#  ['Jordan',
#   '1,746,997',
#   '',
#   '14,122                                ',
#   '',
#   '1,731,007',
#   '',
#   '1,868',
#   '59',
#   '10,300,869 '],
#  ['Ireland',
#   '1,693,847',
#   '',
#   '8,339                                ',
#   '',
#   '1,675,433',
#   '+53',
#   '10,075',
#   '36',
#   '5,020,199 '],
#  ['Pakistan',
#   '1,575,992',
#   '+15',
#   '30,639                                ',
#   '',
#   '1,538,689',
#   '',
#   '6,664',
#   '17',
#   '229,488,994 '],
#  ['Norway',
#   '1,476,541',
#   '',
#   '4,571                                ',
#   '',
#   '1,469,346',
#   '',
#   '2,624',
#   '20',
#   '5,511,370 '],
#  ['Finland',
#   '1,446,397',
#   '',
#   '8,263                                ',
#   '',
#   '1,425,662',
#   '+1,317',
#   '12,472',
#   '21',
#   '5,554,960 '],
#  ['Kazakhstan',
#   '1,404,504',
#   '+175',
#   '13,695                                ',
#   '',
#   '1,383,020',
#   '',
#   '7,789',
#   '24',
#   '19,205,043 '],
#  ['Slovenia',
#   '1,315,101',
#   '',
#   '7,029                                ',
#   '',
#   '1,294,252',
#   '',
#   '13,820',
#   '21',
#   '2,078,034 '],
#  ['Bulgaria',
#   '1,293,684',
#   '',
#   '38,130                                ',
#   '',
#   '1,251,436',
#   '',
#   '4,118',
#   '41',
#   '6,844,597 '],
#  ['Lithuania',
#   '1,291,464',
#   '',
#   '9,505                                ',
#   '',
#   '1,275,308',
#   '',
#   '6,651',
#   '8',
#   '2,661,708 '],
#  ['Morocco',
#   '1,271,942',
#   '',
#   '16,295                                ',
#   '',
#   '1,255,319',
#   '',
#   '328',
#   '293',
#   '37,772,756 '],
#  ['Croatia',
#   '1,265,719',
#   '',
#   '17,719                                ',
#   '',
#   '1,246,601',
#   '',
#   '1,399',
#   '29',
#   '4,059,286 '],
#  ['Lebanon',
#   '1,224,238',
#   '',
#   '10,756                                ',
#   '',
#   '1,087,587',
#   '',
#   '125,895',
#   '74',
#   '6,684,849 '],
#  ['Guatemala',
#   '1,213,139',
#   '',
#   '20,027                                ',
#   '',
#   '1,179,448',
#   '',
#   '13,664',
#   '5',
#   '18,584,039 '],
#  ['Bolivia',
#   '1,174,694',
#   '+1,555',
#   '22,324                                ',
#   '+1',
#   '1,123,744',
#   '+1,249',
#   '28,626',
#   '220',
#   '11,992,656 '],
#  ['Costa Rica',
#   '1,171,802',
#   '',
#   '9,104                                ',
#   '',
#   '860,711',
#   '',
#   '301,987',
#   '52',
#   '5,182,354 '],
#  ['Tunisia',
#   '1,147,729',
#   '',
#   '29,288                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '44',
#   '12,046,656 '],
#  ['Cuba',
#   '1,112,197',
#   '',
#   '8,530                                ',
#   '',
#   '1,103,508',
#   '',
#   '159',
#   '23',
#   '11,305,652 '],
#  ['UAE',
#   '1,047,694',
#   '',
#   '2,348                                ',
#   '',
#   '1,030,711',
#   '',
#   '14,635',
#   '',
#   '10,081,785 '],
#  ['Ecuador',
#   '1,040,463',
#   '',
#   '35,940                                ',
#   '',
#   '1,003,412',
#   '+1,110',
#   '1,111',
#   '759',
#   '18,113,361 '],
#  ['Panama',
#   '1,027,247',
#   '',
#   '8,584                                ',
#   '',
#   '1,016,577',
#   '',
#   '2,086',
#   '16',
#   '4,446,964 '],
#  ['Uruguay',
#   '1,025,810',
#   '',
#   '7,586                                ',
#   '',
#   '1,013,059',
#   '',
#   '5,165',
#   '18',
#   '3,496,016 '],
#  ['Mongolia',
#   '1,007,787',
#   '',
#   '2,179                                ',
#   '',
#   '1,005,087',
#   '',
#   '521',
#   '192',
#   '3,378,078 '],
#  ['Nepal',
#   '1,001,031',
#   '',
#   '12,020                                ',
#   '',
#   '988,986',
#   '',
#   '25',
#   '',
#   '30,225,582 '],
#  ['Belarus',
#   '994,037',
#   '',
#   '7,118                                ',
#   '',
#   '985,592',
#   '',
#   '1,327',
#   '',
#   '9,432,800 '],
#  ['Latvia',
#   '974,744',
#   '',
#   '6,181                                ',
#   '',
#   '966,958',
#   '',
#   '1,605',
#   '13',
#   '1,848,837 '],
#  ['Saudi Arabia',
#   '827,275',
#   '',
#   '9,534                                ',
#   '',
#   '814,911',
#   '',
#   '2,830',
#   '25',
#   '35,844,909 '],
#  ['Azerbaijan',
#   '826,993',
#   '',
#   '10,027                                ',
#   '',
#   '816,434',
#   '',
#   '532',
#   '',
#   '10,300,205 '],
#  ['Paraguay',
#   '798,231',
#   '',
#   '19,716                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '7,305,843 '],
#  ['Bahrain',
#   '699,313',
#   '',
#   '1,539                                ',
#   '',
#   '697,225',
#   '',
#   '549',
#   '2,405',
#   '1,783,983 '],
#  ['Sri Lanka',
#   '671,942',
#   '',
#   '16,820                                ',
#   '',
#   '655,081',
#   '',
#   '41',
#   '',
#   '21,575,842 '],
#  ['Kuwait',
#   '662,747',
#   '',
#   '2,570                                ',
#   '',
#   '660,095',
#   '',
#   '82',
#   '',
#   '4,380,326 '],
#  ['Dominican Republic',
#   '650,990',
#   '',
#   '4,384                                ',
#   '',
#   '644,785',
#   '',
#   '1,821',
#   '4',
#   '11,056,370 '],
#  ['Cyprus',
#   '634,709',
#   '',
#   '1,262                                ',
#   '',
#   '624,300',
#   '',
#   '9,147',
#   '60',
#   '1,223,387 '],
#  ['Myanmar',
#   '633,726',
#   '',
#   '19,490                                ',
#   '',
#   '614,165',
#   '',
#   '71',
#   '',
#   '55,227,143 '],
#  ['Palestine',
#   '621,008',
#   '',
#   '5,404                                ',
#   '',
#   '615,445',
#   '',
#   '159',
#   '17',
#   '5,345,541 '],
#  ['Estonia',
#   '612,829',
#   '',
#   '2,885                                ',
#   '',
#   '524,990',
#   '',
#   '84,954',
#   '9',
#   '1,321,910 '],
#  ['Moldova',
#   '597,216',
#   '',
#   '11,940                                ',
#   '',
#   '504,142',
#   '',
#   '81,134',
#   '49',
#   '4,013,171 '],
#  ['Venezuela',
#   '550,779',
#   '',
#   '5,834                                ',
#   '',
#   '544,198',
#   '',
#   '747',
#   '36',
#   '29,266,991 '],
#  ['Egypt',
#   '515,645',
#   '',
#   '24,613                                ',
#   '',
#   '442,182',
#   '',
#   '48,850',
#   '122',
#   '106,156,692 '],
#  ['Libya',
#   '507,153',
#   '',
#   '6,437                                ',
#   '',
#   '500,675',
#   '',
#   '41',
#   '',
#   '7,040,745 '],
#  ['Ethiopia',
#   '498,832',
#   '',
#   '7,572                                ',
#   '',
#   '483,654',
#   '',
#   '7,606',
#   '',
#   '120,812,698 '],
#  ['Qatar',
#   '490,946',
#   '',
#   '685                                ',
#   '',
#   '489,705',
#   '',
#   '556',
#   '1',
#   '2,979,915 '],
#  ['Réunion',
#   '480,501',
#   '',
#   '907                                ',
#   '',
#   '418,572',
#   '',
#   '61,022',
#   '10',
#   '908,061 '],
#  ['Honduras',
#   '468,048',
#   '',
#   '11,088                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '105',
#   '10,221,247 '],
#  ['Armenia',
#   '445,976',
#   '',
#   '8,716                                ',
#   '',
#   '435,162',
#   '',
#   '2,098',
#   '',
#   '2,971,966 '],
#  ['Bosnia and Herzegovina',
#   '401,125',
#   '',
#   '16,239                                ',
#   '',
#   '378,880',
#   '',
#   '6,006',
#   '',
#   '3,249,317 '],
#  ['Oman',
#   '399,154',
#   '',
#   '4,260                                ',
#   '',
#   '384,669',
#   '',
#   '10,225',
#   '2',
#   '5,323,993 '],
#  ['North Macedonia',
#   '346,095',
#   '',
#   '9,623                                ',
#   '',
#   '336,215',
#   '',
#   '257',
#   '',
#   '2,081,304 '],
#  ['Kenya',
#   '342,617',
#   '',
#   '5,688                                ',
#   '',
#   '336,811',
#   '',
#   '118',
#   '1',
#   '56,215,221 '],
#  ['Zambia',
#   '335,980',
#   '',
#   '4,030                                ',
#   '',
#   '330,635',
#   '',
#   '1,315',
#   '',
#   '19,470,234 '],
#  ['Albania',
#   '333,995',
#   '',
#   '3,595                                ',
#   '',
#   '328,719',
#   '',
#   '1,681',
#   '',
#   '2,866,374 '],
#  ['Botswana',
#   '328,230',
#   '',
#   '2,795                                ',
#   '',
#   '323,747',
#   '',
#   '1,688',
#   '1',
#   '2,441,162 '],
#  ['Luxembourg',
#   '297,757',
#   '',
#   '1,133                                ',
#   '',
#   '288,991',
#   '',
#   '7,633',
#   '',
#   '642,371 '],
#  ['Montenegro',
#   '285,247',
#   '',
#   '2,792                                ',
#   '',
#   '281,969',
#   '',
#   '486',
#   '6',
#   '627,950 '],
#  ['Algeria',
#   '271,262',
#   '',
#   '6,881                                ',
#   '',
#   '182,671',
#   '',
#   '81,710',
#   '',
#   '45,350,148 '],
#  ['Brunei ',
#   '270,199',
#   '',
#   '225                                ',
#   '',
#   '243,601',
#   '',
#   '26,373',
#   '3',
#   '445,431 '],
#  ['Nigeria',
#   '266,463',
#   '',
#   '3,155                                ',
#   '',
#   '259,850',
#   '',
#   '3,458',
#   '11',
#   '216,746,934 '],
#  ['Zimbabwe',
#   '259,981',
#   '',
#   '5,637                                ',
#   '',
#   '253,677',
#   '',
#   '667',
#   '12',
#   '15,331,428 '],
#  ['Uzbekistan',
#   '250,066',
#   '',
#   '1,637                                ',
#   '',
#   '241,486',
#   '',
#   '6,943',
#   '23',
#   '34,382,084 '],
#  ['Mozambique',
#   '231,219',
#   '',
#   '2,232                                ',
#   '',
#   '228,801',
#   '',
#   '186',
#   '11',
#   '33,089,461 '],
#  ['Martinique',
#   '228,171',
#   '',
#   '1,085                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '8',
#   '374,087 '],
#  ['Laos',
#   '217,901',
#   '+14',
#   '758                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '7,481,023 '],
#  ['Iceland',
#   '208,459',
#   '',
#   '229                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '2',
#   '345,393 '],
#  ['Afghanistan',
#   '207,866',
#   '',
#   '7,854                                ',
#   '',
#   '185,747',
#   '',
#   '14,265',
#   '1,124',
#   '40,754,388 '],
#  ['Kyrgyzstan',
#   '206,586',
#   '',
#   '2,991                                ',
#   '',
#   '196,406',
#   '',
#   '7,189',
#   '131',
#   '6,728,271 '],
#  ['El Salvador',
#   '201,785',
#   '',
#   '4,230                                ',
#   '',
#   '179,410',
#   '',
#   '18,145',
#   '8',
#   '6,550,389 '],
#  ['Guadeloupe',
#   '200,965',
#   '',
#   '1,003                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '19',
#   '399,794 '],
#  ['Trinidad and Tobago',
#   '186,685',
#   '',
#   '4,297                                ',
#   '',
#   '182,182',
#   '',
#   '206',
#   '8',
#   '1,406,585 '],
#  ['Maldives',
#   '185,702',
#   '',
#   '311                                ',
#   '',
#   '163,687',
#   '',
#   '21,704',
#   '25',
#   '540,985 '],
#  ['Ghana',
#   '171,065',
#   '',
#   '1,461                                ',
#   '',
#   '169,586',
#   '',
#   '18',
#   '2',
#   '32,395,450 '],
#  ['Namibia',
#   '170,295',
#   '',
#   '4,082                                ',
#   '',
#   '165,961',
#   '',
#   '252',
#   '',
#   '2,633,874 '],
#  ['Uganda',
#   '170,209',
#   '',
#   '3,630                                ',
#   '',
#   '100,431',
#   '',
#   '66,148',
#   '3',
#   '48,432,863 '],
#  ['Jamaica',
#   '152,827',
#   '',
#   '3,465                                ',
#   '',
#   '101,996',
#   '',
#   '47,366',
#   '',
#   '2,985,094 '],
#  ['Cambodia',
#   '138,642',
#   '+4',
#   '3,056                                ',
#   '',
#   '135,565',
#   '+9',
#   '21',
#   '',
#   '17,168,639 '],
#  ['Rwanda',
#   '133,063',
#   '',
#   '1,468                                ',
#   '',
#   '131,112',
#   '',
#   '483',
#   '',
#   '13,600,464 '],
#  ['Cameroon',
#   '123,993',
#   '',
#   '1,965                                ',
#   '',
#   '118,616',
#   '',
#   '3,412',
#   '13',
#   '27,911,548 '],
#  ['Malta',
#   '116,704',
#   '',
#   '822                                ',
#   '',
#   '115,068',
#   '',
#   '814',
#   '4',
#   '444,033 '],
#  ['Barbados',
#   '105,905',
#   '',
#   '569                                ',
#   '',
#   '105,314',
#   '',
#   '22',
#   '',
#   '288,023 '],
#  ['Angola',
#   '105,095',
#   '',
#   '1,930                                ',
#   '',
#   '103,050',
#   '',
#   '115',
#   '',
#   '35,027,343 '],
#  ['Channel Islands',
#   '100,373',
#   '',
#   '219                                ',
#   '',
#   '99,304',
#   '',
#   '850',
#   '',
#   '176,463 '],
#  ['French Guiana',
#   '97,946',
#   '',
#   '415                                ',
#   '',
#   '11,254',
#   '',
#   '86,277',
#   '6',
#   '314,169 '],
#  ['DRC',
#   '95,173',
#   '',
#   '1,462                                ',
#   '',
#   '84,159',
#   '',
#   '9,552',
#   '',
#   '95,240,792 '],
#  ['Senegal',
#   '88,900',
#   '',
#   '1,968                                ',
#   '',
#   '86,915',
#   '',
#   '17',
#   '',
#   '17,653,671 '],
#  ['Malawi',
#   '88,220',
#   '',
#   '2,685                                ',
#   '',
#   '85,065',
#   '',
#   '470',
#   '67',
#   '20,180,839 '],
#  ['Ivory Coast',
#   '87,960',
#   '',
#   '833                                ',
#   '',
#   '87,116',
#   '',
#   '11',
#   '',
#   '27,742,298 '],
#  ['Suriname',
#   '82,020',
#   '',
#   '1,398                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '596,831 '],
#  ['New Caledonia',
#   '79,724',
#   '',
#   '314                                ',
#   '',
#   '79,234',
#   '',
#   '176',
#   '9',
#   '290,915 '],
#  ['French Polynesia',
#   '77,957',
#   '',
#   '649                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '284,164 '],
#  ['Eswatini',
#   '74,053',
#   '',
#   '1,422                                ',
#   '',
#   '72,603',
#   '',
#   '28',
#   '',
#   '1,184,817 '],
#  ['Guyana',
#   '72,538',
#   '',
#   '1,291                                ',
#   '',
#   '70,903',
#   '',
#   '344',
#   '',
#   '794,045 '],
#  ['Belize',
#   '70,397',
#   '',
#   '688                                ',
#   '',
#   '69,605',
#   '',
#   '104',
#   '6',
#   '412,190 '],
#  ['Fiji',
#   '68,771',
#   '',
#   '883                                ',
#   '',
#   '66,730',
#   '',
#   '1,158',
#   '',
#   '909,466 '],
#  ['Madagascar',
#   '67,760',
#   '',
#   '1,418                                ',
#   '',
#   '66,316',
#   '',
#   '26',
#   '',
#   '29,178,077 '],
#  ['Sudan',
#   '63,702',
#   '',
#   '4,995                                ',
#   '',
#   '58,275',
#   '',
#   '432',
#   '',
#   '45,992,020 '],
#  ['Mauritania',
#   '63,429',
#   '',
#   '997                                ',
#   '',
#   '62,423',
#   '',
#   '9',
#   '',
#   '4,901,981 '],
#  ['Cabo Verde',
#   '63,214',
#   '',
#   '412                                ',
#   '',
#   '62,738',
#   '',
#   '64',
#   '23',
#   '567,678 '],
#  ['Bhutan',
#   '62,551',
#   '',
#   '21                                ',
#   '',
#   '61,564',
#   '',
#   '966',
#   '',
#   '787,941 '],
#  ['Syria',
#   '57,423',
#   '',
#   '3,163                                ',
#   '',
#   '54,260',
#   '',
#   '0',
#   '',
#   '19,364,809 '],
#  ['Burundi',
#   '52,162',
#   '',
#   '38                                ',
#   '',
#   '51,393',
#   '',
#   '731',
#   '',
#   '12,624,840 '],
#  ['Seychelles',
#   '50,355',
#   '',
#   '172                                ',
#   '',
#   '50,026',
#   '',
#   '157',
#   '',
#   '99,426 '],
#  ['Gabon',
#   '48,980',
#   '',
#   '306                                ',
#   '',
#   '48,668',
#   '',
#   '6',
#   '',
#   '2,331,533 '],
#  ['Andorra',
#   '47,781',
#   '',
#   '165                                ',
#   '',
#   '47,563',
#   '',
#   '53',
#   '14',
#   '77,463 '],
#  ['Papua New Guinea',
#   '46,663',
#   '',
#   '669                                ',
#   '',
#   '43,982',
#   '',
#   '2,012',
#   '7',
#   '9,292,169 '],
#  ['Curaçao',
#   '45,986',
#   '',
#   '295                                ',
#   '',
#   '44,720',
#   '',
#   '971',
#   '3',
#   '165,529 '],
#  ['Aruba',
#   '43,860',
#   '',
#   '236                                ',
#   '',
#   '42,438',
#   '',
#   '1,186',
#   '2',
#   '107,609 '],
#  ['Tanzania',
#   '42,396',
#   '',
#   '845                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   '63,298,550 '],
#  ['Mayotte',
#   '42,002',
#   '',
#   '188                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '286,259 '],
#  ['Mauritius',
#   '41,541',
#   '',
#   '1,041                                ',
#   '',
#   '39,807',
#   '',
#   '693',
#   '',
#   '1,274,727 '],
#  ['Togo',
#   '39,349',
#   '',
#   '290                                ',
#   '',
#   '39,051',
#   '',
#   '8',
#   '',
#   '8,680,837 '],
#  ['Guinea',
#   '38,210',
#   '',
#   '466                                ',
#   '',
#   '37,292',
#   '',
#   '452',
#   '8',
#   '13,865,691 '],
#  ['Isle of Man',
#   '38,008',
#   '',
#   '116                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '85,732 '],
#  ['Bahamas',
#   '37,491',
#   '',
#   '833                                ',
#   '',
#   '36,366',
#   '',
#   '292',
#   '1',
#   '400,516 '],
#  ['Lesotho',
#   '34,790',
#   '',
#   '723                                ',
#   '',
#   '25,980',
#   '',
#   '8,087',
#   '',
#   '2,175,699 '],
#  ['Faeroe Islands',
#   '34,658',
#   '',
#   '28                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '5',
#   '49,233 '],
#  ['Haiti',
#   '33,969',
#   '',
#   '860                                ',
#   '',
#   '32,977',
#   '',
#   '132',
#   '',
#   '11,680,283 '],
#  ['Mali',
#   '32,771',
#   '',
#   '743                                ',
#   '',
#   '31,951',
#   '',
#   '77',
#   '',
#   '21,473,764 '],
#  ['Cayman Islands',
#   '31,472',
#   '',
#   '37                                ',
#   '',
#   '8,553',
#   '',
#   '22,882',
#   '1',
#   '67,277 '],
#  ['Saint Lucia',
#   '29,759',
#   '',
#   '409                                ',
#   '',
#   '29,095',
#   '',
#   '255',
#   '',
#   '185,113 '],
#  ['Benin',
#   '27,982',
#   '',
#   '163                                ',
#   '',
#   '27,817',
#   '',
#   '2',
#   '',
#   '12,784,726 '],
#  ['Somalia',
#   '27,310',
#   '',
#   '1,361                                ',
#   '',
#   '13,182',
#   '',
#   '12,767',
#   '',
#   '16,841,795 '],
#  ['Congo',
#   '25,375',
#   '',
#   '386                                ',
#   '',
#   '24,006',
#   '',
#   '983',
#   '',
#   '5,797,805 '],
#  ['Solomon Islands',
#   '24,575',
#   '',
#   '153                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '1',
#   '721,159 '],
#  ['Timor-Leste',
#   '23,403',
#   '',
#   '138                                ',
#   '',
#   '23,102',
#   '',
#   '163',
#   '',
#   '1,369,429 '],
#  ['San Marino',
#   '23,290',
#   '',
#   '121                                ',
#   '',
#   '23,034',
#   '',
#   '135',
#   '4',
#   '34,085 '],
#  ['Micronesia',
#   '22,247',
#   '',
#   '58                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '1',
#   '117,489 '],
#  ['Burkina Faso',
#   '22,023',
#   '',
#   '395                                ',
#   '',
#   '21,596',
#   '',
#   '32',
#   '',
#   '22,102,838 '],
#  ['Liechtenstein',
#   '21,305',
#   '',
#   '88                                ',
#   '',
#   '21,186',
#   '',
#   '31',
#   '',
#   '38,387 '],
#  ['Gibraltar',
#   '20,342',
#   '',
#   '111                                ',
#   '',
#   '16,579',
#   '',
#   '3,652',
#   '',
#   '33,704 '],
#  ['Grenada',
#   '19,680',
#   '',
#   '238                                ',
#   '',
#   '19,358',
#   '',
#   '84',
#   '4',
#   '113,475 '],
#  ['Bermuda',
#   '18,684',
#   '',
#   '154                                ',
#   '',
#   '18,465',
#   '',
#   '65',
#   '',
#   '61,939 '],
#  ['Nicaragua',
#   '18,491',
#   '',
#   '225                                ',
#   '',
#   '4,225',
#   '',
#   '14,041',
#   '',
#   '6,779,100 '],
#  ['South Sudan',
#   '18,368',
#   '',
#   '138                                ',
#   '',
#   '18,115',
#   '',
#   '115',
#   '1',
#   '11,618,511 '],
#  ['Tajikistan',
#   '17,786',
#   '',
#   '125                                ',
#   '',
#   '17,264',
#   '',
#   '397',
#   '',
#   '9,957,464 '],
#  ['Equatorial Guinea',
#   '17,186',
#   '',
#   '183                                ',
#   '',
#   '16,880',
#   '',
#   '123',
#   '5',
#   '1,496,662 '],
#  ['Tonga',
#   '16,487',
#   '',
#   '12                                ',
#   '',
#   '15,638',
#   '',
#   '837',
#   '',
#   '107,749 '],
#  ['Monaco',
#   '16,004',
#   '',
#   '65                                ',
#   '',
#   '15,915',
#   '',
#   '24',
#   '4',
#   '39,783 '],
#  ['Samoa',
#   '15,991',
#   '',
#   '29                                ',
#   '',
#   '1,605',
#   '',
#   '14,357',
#   '4',
#   '202,239 '],
#  ['Dominica',
#   '15,760',
#   '',
#   '74                                ',
#   '',
#   '15,673',
#   '',
#   '13',
#   '',
#   '72,344 '],
#  ['Djibouti',
#   '15,690',
#   '',
#   '189                                ',
#   '',
#   '15,427',
#   '',
#   '74',
#   '',
#   '1,016,097 '],
#  ['Marshall Islands',
#   '15,554',
#   '',
#   '17                                ',
#   '',
#   '15,528',
#   '',
#   '9',
#   '',
#   '60,057 '],
#  ['CAR',
#   '15,351',
#   '',
#   '113                                ',
#   '',
#   '14,615',
#   '',
#   '623',
#   '2',
#   '5,016,678 '],
#  ['Gambia',
#   '12,586',
#   '',
#   '372                                ',
#   '',
#   '12,189',
#   '',
#   '25',
#   '',
#   '2,558,482 '],
#  ['Saint Martin',
#   '12,222',
#   '',
#   '63                                ',
#   '',
#   '1,399',
#   '',
#   '10,760',
#   '7',
#   '39,730 '],
#  ['Vanuatu',
#   '12,014',
#   '',
#   '14                                ',
#   '',
#   '11,976',
#   '',
#   '24',
#   '',
#   '321,832 '],
#  ['Greenland',
#   '11,971',
#   '',
#   '21                                ',
#   '',
#   '2,761',
#   '',
#   '9,189',
#   '4',
#   '56,973 '],
#  ['Yemen',
#   '11,945',
#   '',
#   '2,159                                ',
#   '',
#   '9,124',
#   '',
#   '662',
#   '23',
#   '31,154,867 '],
#  ['Caribbean Netherlands',
#   '11,635',
#   '',
#   '38                                ',
#   '',
#   '10,476',
#   '',
#   '1,121',
#   '',
#   '26,647 '],
#  ['Sint Maarten',
#   '10,998',
#   '',
#   '89                                ',
#   '',
#   '10,905',
#   '',
#   '4',
#   '',
#   '43,966 '],
#  ['Eritrea',
#   '10,189',
#   '',
#   '103                                ',
#   '',
#   '10,086',
#   '',
#   '0',
#   '',
#   '3,662,244 '],
#  ['Niger',
#   '9,931',
#   '',
#   '312                                ',
#   '',
#   '8,890',
#   '',
#   '729',
#   '1',
#   '26,083,660 '],
#  ['St. Vincent Grenadines',
#   '9,552',
#   '',
#   '120                                ',
#   '',
#   '9,409',
#   '',
#   '23',
#   '',
#   '111,551 '],
#  ['Antigua and Barbuda',
#   '9,106',
#   '',
#   '146                                ',
#   '',
#   '8,954',
#   '',
#   '6',
#   '1',
#   '99,509 '],
#  ['Comoros',
#   '8,986',
#   '',
#   '161                                ',
#   '',
#   '8,822',
#   '',
#   '3',
#   '',
#   '907,419 '],
#  ['Guinea-Bissau',
#   '8,947',
#   '',
#   '176                                ',
#   '',
#   '8,656',
#   '',
#   '115',
#   '6',
#   '2,063,367 '],
#  ['Liberia',
#   '8,043',
#   '',
#   '294                                ',
#   '',
#   '7,741',
#   '',
#   '8',
#   '2',
#   '5,305,117 '],
#  ['Sierra Leone',
#   '7,760',
#   '',
#   '126                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '8,306,436 '],
#  ['Chad',
#   '7,651',
#   '',
#   '194                                ',
#   '',
#   '4,874',
#   '',
#   '2,583',
#   '',
#   '17,413,580 '],
#  ['British Virgin Islands',
#   '7,305',
#   '',
#   '64                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '30,596 '],
#  ['Cook Islands',
#   '6,860',
#   '',
#   '1                                ',
#   '',
#   '6,782',
#   '',
#   '77',
#   '',
#   '17,571 '],
#  ['Saint Kitts and Nevis',
#   '6,573',
#   '',
#   '46                                ',
#   '',
#   '6,521',
#   '',
#   '6',
#   '',
#   '53,871 '],
#  ['Turks and Caicos',
#   '6,479',
#   '',
#   '36                                ',
#   '',
#   '6,423',
#   '',
#   '20',
#   '4',
#   '39,741 '],
#  ['Sao Tome and Principe',
#   '6,279',
#   '',
#   '77                                ',
#   '',
#   '6,202',
#   '',
#   '0',
#   '',
#   '227,679 '],
#  ['Palau',
#   '5,976',
#   '',
#   '9                                ',
#   '',
#   '5,965',
#   '',
#   '2',
#   '1',
#   '18,233 '],
#  ['St. Barth',
#   '5,418',
#   '',
#   '6                                ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '',
#   '9,945 '],
#  ['Nauru',
#   '4,621',
#   '',
#   '1                                ',
#   '',
#   '4,609',
#   '',
#   '11',
#   '',
#   '10,903 '],
#  ['Anguilla',
#   '3,904',
#   '',
#   '12                                ',
#   '',
#   '3,879',
#   '',
#   '13',
#   '4',
#   '15,230 '],
#  ['Kiribati',
#   '3,430',
#   '',
#   '13                                ',
#   '',
#   '2,703',
#   '',
#   '714',
#   '3',
#   '123,419 '],
#  ['Wallis and Futuna',
#   '3,427',
#   '',
#   '7                                ',
#   '',
#   '438',
#   '',
#   '2,982',
#   '',
#   '10,982 '],
#  ['Macao',
#   '3,360',
#   '',
#   '91                                ',
#   '',
#   '3,047',
#   '',
#   '222',
#   '',
#   '667,490 '],
#  ['Saint Pierre Miquelon',
#   '3,349',
#   '',
#   '2                                ',
#   '',
#   '2,449',
#   '',
#   '898',
#   '1',
#   '5,759 '],
#  ['Tuvalu', '2,805', '', ' ', '', '', '', '2,805', '', '12,066 '],
#  ['Falkland Islands', '1,930', '', ' ', '', '1,930', '', '0', '', '3,539 '],
#  ['Saint Helena', '1,806', '', ' ', '', '2', '', '1,804', '', '6,115 '],
#  ['Montserrat',
#   '1,403',
#   '',
#   '8                                ',
#   '',
#   '1,376',
#   '',
#   '19',
#   '',
#   '4,965 '],
#  ['Diamond Princess',
#   '712',
#   '',
#   '13                                ',
#   '',
#   '699',
#   '',
#   '0',
#   '',
#   ' '],
#  ['Niue', '644', '', ' ', '', '495', '', '149', '', '1,622 '],
#  ['Vatican City', '29', '', ' ', '', '29', '', '0', '', '799 '],
#  ['Western Sahara',
#   '10',
#   '',
#   '1                                ',
#   '',
#   '9',
#   '',
#   '0',
#   '',
#   '626,161 '],
#  ['MS Zaandam',
#   '9',
#   '',
#   '2                                ',
#   '',
#   '7',
#   '',
#   '0',
#   '',
#   ' '],
#  ['Tokelau', '5', '', ' ', '', '', '', '5', '', '1,378 '],
#  ['China',
#   '503,302',
#   '',
#   '5,272                                ',
#   '',
#   '379,053',
#   '',
#   '118,977',
#   '7,557',
#   '1,448,471,400                                ']]

# %%
import pandas as pd

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                   0            1 2   \
# 0               USA  103,151,843
# 1             India   44,681,523
# 2            France   39,421,144
# 3           Germany   37,562,191
# 4            Brazil   36,560,497
# ..              ...          ... ..
# 226    Vatican City           29
# 227  Western Sahara           10
# 228      MS Zaandam            9
# 229         Tokelau            5
# 230           China      503,302
#
#                                              3 4             5        6  \
# 0    1,121,725                                     100,061,532
# 1      530,722                                      44,147,322
# 2      163,105                                      38,862,625
# 3      163,244                                      36,946,600  +40,900
# 4      695,031                                      35,429,017
# ..                                         ... ..          ...      ...
# 226                                                         29
# 227          1                                               9
# 228          2                                               7
# 229
# 230      5,272                                         379,053
#
#              7      8                                              9
# 0    1,968,586  4,815                                   334,805,269
# 1        3,479    698                                 1,406,631,776
# 2      395,414    869                                    65,584,518
# 3      452,347  1,281                                    83,883,596
# 4      436,449  8,318                                   215,353,593
# ..         ...    ...                                            ...
# 226          0                                                  799
# 227          0                                              626,161
# 228          0
# 229          5                                                1,378
# 230    118,977  7,557  1,448,471,400
#
# [231 rows x 10 columns]

# %%
column_name=['country',
         'Totalcase',
         'Newcase',
         'TotalDeath',
         'Newdeath',
         'TotalRecovered',
         'Newrecovered',
         'Activecases',
         'Serious/critical',
         'Population']

# %%
len(columns)
# Out:
# 10

# %%
df.columns=column_name

# %%
df.head()
# Out:
#    country    Totalcase Newcase                                 TotalDeath  \
# 0      USA  103,151,843          1,121,725
# 1    India   44,681,523            530,722
# 2   France   39,421,144            163,105
# 3  Germany   37,562,191            163,244
# 4   Brazil   36,560,497            695,031
#
#   Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 0             100,061,532                1,968,586            4,815
# 1              44,147,322                    3,479              698
# 2              38,862,625                  395,414              869
# 3              36,946,600      +40,900     452,347            1,281
# 4              35,429,017                  436,449            8,318
#
#        Population
# 0    334,805,269
# 1  1,406,631,776
# 2     65,584,518
# 3     83,883,596
# 4    215,353,593

# %%
df.head(20)
# Out:
#         country    Totalcase  Newcase  \
# 0           USA  103,151,843
# 1         India   44,681,523
# 2        France   39,421,144
# 3       Germany   37,562,191
# 4        Brazil   36,560,497
# 5         Japan   30,647,859
# 6      S. Korea   29,654,090  +54,343
# 7         Italy   25,279,682
# 8            UK   24,210,131
# 9        Russia   21,832,768
# 10       Turkey   17,042,722
# 11        Spain   13,693,478
# 12      Vietnam   11,525,911
# 13    Australia   11,211,305   +1,150
# 14    Argentina   10,004,679
# 15       Taiwan    9,097,554
# 16  Netherlands    8,576,523
# 17         Iran    7,562,169
# 18       Mexico    7,284,502
# 19    Indonesia    6,724,281
#
#                                    TotalDeath Newdeath TotalRecovered  \
# 0   1,121,725                                             100,061,532
# 1     530,722                                              44,147,322
# 2     163,105                                              38,862,625
# 3     163,244                                              36,946,600
# 4     695,031                                              35,429,017
# 5      60,411                                              21,271,832
# 6      32,745                                      +76     28,567,938
# 7     185,417                                              24,688,083
# 8     201,028                                              23,895,374
# 9     394,168                                              21,253,611
# 10    101,492                                                     N/A
# 11    117,413                                              13,502,806
# 12     43,186                                              10,611,547
# 13     17,380                                      +31     11,052,693
# 14    130,249                                               9,707,830
# 15     15,608                                               8,609,056
# 16     22,989                                               8,528,649
# 17    144,717                                               7,336,524
# 18    331,333                                               6,519,926
# 19    160,697                                               6,555,664
#
#    Newrecovered Activecases Serious/critical      Population
# 0                 1,968,586            4,815    334,805,269
# 1                     3,479              698  1,406,631,776
# 2                   395,414              869     65,584,518
# 3       +40,900     452,347            1,281     83,883,596
# 4                   436,449            8,318    215,353,593
# 5                 9,315,616              656    125,584,838
# 6       +66,005   1,053,407              540     51,329,899
# 7                   406,182              319     60,262,770
# 8        +6,508     113,729              146     68,497,907
# 9                   184,989            2,300    145,805,947
# 10          N/A         N/A                      85,561,976
# 11                   73,259              231     46,719,142
# 12                  871,178               12     98,953,541
# 13                  141,232              109     26,068,792
# 14       +8,843     166,600              402     46,010,234
# 15                  472,890                      23,888,595
# 16                   24,885               55     17,211,447
# 17                   80,928              167     86,022,837
# 18                  433,243            4,798    131,562,772
# 19                    7,920            2,771    279,134,505

# %%
df.tail()
# Out:
#             country Totalcase Newcase                             TotalDeath  \
# 226    Vatican City        29
# 227  Western Sahara        10              1
# 228      MS Zaandam         9              2
# 229         Tokelau         5
# 230           China   503,302          5,272
#
#     Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 226                      29                        0
# 227                       9                        0
# 228                       7                        0
# 229                                                5
# 230                 379,053                  118,977            7,557
#
#                                         Population
# 226                                           799
# 227                                       626,161
# 228
# 229                                         1,378
# 230  1,448,471,400

# %%
df.to_csv('covid_datajan11.csv',index=False)

# %%
# CSV = comma serprated value

# %% [markdown]
# # read csv file

# %%
df=pd.read_csv('covid_datajan11.csv')

# %%
df.head()
# Out:
#    country    Totalcase Newcase                                 TotalDeath  \
# 0      USA  103,151,843     NaN  1,121,725
# 1    India   44,681,523     NaN    530,722
# 2   France   39,421,144     NaN    163,105
# 3  Germany   37,562,191     NaN    163,244
# 4   Brazil   36,560,497     NaN    695,031
#
#    Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 0       NaN    100,061,532          NaN   1,968,586            4,815
# 1       NaN     44,147,322          NaN       3,479              698
# 2       NaN     38,862,625          NaN     395,414              869
# 3       NaN     36,946,600      +40,900     452,347            1,281
# 4       NaN     35,429,017          NaN     436,449            8,318
#
#        Population
# 0    334,805,269
# 1  1,406,631,776
# 2     65,584,518
# 3     83,883,596
# 4    215,353,593

# %% [markdown]
# # NaN means missing data

# %%
df.isnull()
# Out:
#      country  Totalcase  Newcase  TotalDeath  Newdeath  TotalRecovered  \
# 0      False      False     True       False      True           False
# 1      False      False     True       False      True           False
# 2      False      False     True       False      True           False
# 3      False      False     True       False      True           False
# 4      False      False     True       False      True           False
# ..       ...        ...      ...         ...       ...             ...
# 226    False      False     True       False      True           False
# 227    False      False     True       False      True           False
# 228    False      False     True       False      True           False
# 229    False      False     True       False      True            True
# 230    False      False     True       False      True           False
#
#      Newrecovered  Activecases  Serious/critical  Population
# 0            True        False             False       False
# 1            True        False             False       False
# 2            True        False             False       False
# 3           False        False             False       False
# 4            True        False             False       False
# ..            ...          ...               ...         ...
# 226          True        False              True       False
# 227          True        False              True       False
# 228          True        False              True       False
# 229          True        False              True       False
# 230          True        False             False       False
#
# [231 rows x 10 columns]

# %%
True + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %%
True + False
# Out:
# 1

# %%
df.isnull().sum()
# Out:
# country               0
# Totalcase             0
# Newcase             224
# TotalDeath            0
# Newdeath            228
# TotalRecovered       21
# Newrecovered        216
# Activecases          19
# Serious/critical     95
# Population            0
# dtype: int64

# %%
df.isnull().sum().plot.bar()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot: >

# %%
df.isnull().sum().plot.pie()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Heatmap Plot of missing data

# %%
import seaborn as sns

# %%
df.isnull().transpose()
# Out:
#                     0      1      2      3      4      5      6      7    \
# country           False  False  False  False  False  False  False  False
# Totalcase         False  False  False  False  False  False  False  False
# Newcase            True   True   True   True   True   True  False   True
# TotalDeath        False  False  False  False  False  False  False  False
# Newdeath           True   True   True   True   True   True  False   True
# TotalRecovered    False  False  False  False  False  False  False  False
# Newrecovered       True   True   True  False   True   True  False   True
# Activecases       False  False  False  False  False  False  False  False
# Serious/critical  False  False  False  False  False  False  False  False
# Population        False  False  False  False  False  False  False  False
#
#                     8      9    ...    221    222    223    224    225    226  \
# country           False  False  ...  False  False  False  False  False  False
# Totalcase         False  False  ...  False  False  False  False  False  False
# Newcase            True   True  ...   True   True   True   True   True   True
# TotalDeath        False  False  ...  False  False  False  False  False  False
# Newdeath           True   True  ...   True   True   True   True   True   True
# TotalRecovered    False  False  ...  False  False  False  False  False  False
# Newrecovered      False   True  ...   True   True   True   True   True   True
# Activecases       False  False  ...  False  False  False  False  False  False
# Serious/critical  False  False  ...   True   True   True   True   True   True
# Population        False  False  ...  False  False  False  False  False  False
#
#                     227    228    229    230
# country           False  False  False  False
# Totalcase         False  False  False  False
# Newcase            True   True   True   True
# TotalDeath        False  False  False  False
# Newdeath           True   True   True   True
# TotalRecovered    False  False   True  False
# Newrecovered       True   True   True   True
# Activecases       False  False  False  False
# Serious/critical   True   True   True  False
# Population        False  False  False  False
#
# [10 rows x 231 columns]

# %%
sns.heatmap(df.isnull().transpose())
# Out:
# <AxesSubplot: >

# %%
sns.heatmap([[30,29,47,80]])
# Out:
# <AxesSubplot: >

# %%
sns.heatmap([[0,1]])
# Out:
# <AxesSubplot: >

# %%
sns.heatmap([[True,False]])
# Out:
# <AxesSubplot: >

# %%
df.loc[df.country=="Nepal"]
# Out:
#    country  Totalcase Newcase                              TotalDeath  \
# 72   Nepal  1,001,031     NaN  12,020
#
#     Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 72       NaN        988,986          NaN          25              NaN
#
#      Population
# 72  30,225,582

# %%
df.loc[df.country=="Germany"]
# Out:
#    country   Totalcase Newcase                               TotalDeath  \
# 3  Germany  37,562,191     NaN  163,244
#
#    Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 3       NaN     36,946,600      +40,900     452,347            1,281
#
#     Population
# 3  83,883,596

# %%
df.loc[df.country=="Australia"]
# Out:
#       country   Totalcase Newcase                              TotalDeath  \
# 13  Australia  11,211,305  +1,150  17,380
#
#     Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 13      31.0     11,052,693          NaN     141,232              109
#
#      Population
# 13  26,068,792

# %%
df.loc[df.country=="USA"]
# Out:
#   country    Totalcase Newcase                                 TotalDeath  \
# 0     USA  103,151,843     NaN  1,121,725
#
#    Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 0       NaN    100,061,532          NaN   1,968,586            4,815
#
#      Population
# 0  334,805,269

# %%
df['country']
# Out:
# 0                 USA
# 1               India
# 2              France
# 3             Germany
# 4              Brazil
#             ...
# 226      Vatican City
# 227    Western Sahara
# 228        MS Zaandam
# 229           Tokelau
# 230             China
# Name: country, Length: 231, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Scatterplot

# %%
import matplotlib.pyplot as plt

# %%
x=range(8,50,2)
y=[item * 0.1 for item in x]

# %%
plt.scatter(x=x,y=y)

# %%
plt.scatter(x=x,y=y, color='red')    #Scatterplot

# %% [markdown]
# # linechart

# %%
plt.plot(x,y,'o--',color='r')
