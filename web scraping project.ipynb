# %%
url='https://www.worldometers.info/coronavirus/'

# %%
# !pip install beautifulsoup4   tree ma conv garxa
# !pip install lxml
# !pip install requests   html lai reqst pathauxa
# !pip install pandas
# !pip install seaborn    Heatmap ko lagi =heatmap le color bar dinxa
# !pip install matplotlib   daigram/pichart ma draw garxa

# %%
import requests

# %%
html=requests.get(url).content

# %%
type(html)
# Out:
# bytes

# %%
from bs4 import BeautifulSoup

# %%
soup =BeautifulSoup(html,'html.parser')

# %%
tb=soup.find('tbody')

# %%
tr=tb.find_all('tr')

# %%
tr[9]
# Out:
# <tr style="">
# <td style="font-size:12px;color: grey;text-align:center;vertical-align:middle;">2</td>
# <td style="font-weight: bold; font-size:15px; text-align:left;"><a class="mt_a" href="country/india/">India</a></td>
# <td style="font-weight: bold; text-align:right">44,681,884</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="font-weight: bold; text-align:right;">530,726                                </td>
# <td style="font-weight: bold;
#                                     text-align:right;"></td>
# <td style="font-weight: bold; text-align:right">44,148,472</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="text-align:right;font-weight:bold;">2,686</td>
# <td style="font-weight: bold; text-align:right">698</td>
# <td style="font-weight: bold; text-align:right">31,765</td>
# <td style="font-weight: bold; text-align:right">377</td>
# <td style="font-weight: bold; text-align:right">913,255,016</td>
# ...

# %%
all_data=[]
for index in range(8,len(tr)):
    country_data=[]
    table_row=tr[index]
    table_data=table_row.find_all('td')
    
    for item in table_data:
        #print(item.text)
        country_data.append(item.text)
        
    all_data.append(country_data)

# %%
all_data
# Out:
# [['1',
#   'USA',
#   '103,583,983',
#   '',
#   '1,125,558                                ',
#   '',
#   '100,449,206',
#   '',
#   '2,009,219',
#   '4,454',
#   '309,386',
#   '3,362',
#   '1,157,800,576',
#   '3,458,131',
#   '334,805,269 ',
#   'North America',
#   '3',
#   '297',
#   '0',
#   '',
#   '',
#   '6,001'],
#  ['2',
#   'India',
#   '44,681,884',
#   '',
#   '530,726                                ',
#   '',
#   '44,148,472',
#   '',
#   '2,686',
#   '698',
#   '31,765',
#   '377',
#   '913,255,016',
#   '649,250',
#   '1,406,631,776 ',
#   'Asia',
#   '31',
#   '2,650',
#   '2',
#   '',
#   '',
#   '2'],
#  ['3',
#   'France',
#   '39,453,006',
#   '',
#   '163,463                                ',
#   '',
#   '39,056,393',
#   '',
#   '233,150',
#   '869',
#   '601,560',
#   '2,492',
#   '271,490,188',
#   '4,139,547',
#   '65,584,518 ',
#   'Europe',
#   '2',
#   '401',
#   '0',
#   '',
#   '',
#   '3,555'],
#  ['4',
#   'Germany',
#   '37,622,357',
#   '',
# ...

# %%
# 1:10 ra 14

# %%
data=list(map(lambda x:x[1:10]+[x[14]],all_data))

# %%
data
# Out:
# [['USA',
#   '103,583,983',
#   '',
#   '1,125,558                                ',
#   '',
#   '100,449,206',
#   '',
#   '2,009,219',
#   '4,454',
#   '334,805,269 '],
#  ['India',
#   '44,681,884',
#   '',
#   '530,726                                ',
#   '',
#   '44,148,472',
#   '',
#   '2,686',
#   '698',
#   '1,406,631,776 '],
#  ['France',
#   '39,453,006',
#   '',
#   '163,463                                ',
#   '',
#   '39,056,393',
#   '',
#   '233,150',
#   '869',
#   '65,584,518 '],
#  ['Germany',
#   '37,622,357',
#   '',
#   '163,965                                ',
#   '',
#   '37,104,300',
#   '+40,500',
#   '354,092',
#   '1,281',
#   '83,883,596 '],
#  ['Brazil',
#   '36,661,526',
#   '',
#   '695,461                                ',
#   '',
#   '35,580,516',
#   '',
#   '385,549',
#   '8,318',
#   '215,353,593 '],
#  ['Japan',
#   '31,471,011',
#   '',
#   '62,963                                ',
#   '',
#   '21,370,395',
#   '',
#   '10,037,653',
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                   0            1 2   \
# 0               USA  103,583,983
# 1             India   44,681,884
# 2            France   39,453,006
# 3           Germany   37,622,357
# 4            Brazil   36,661,526
# ..              ...          ... ..
# 226    Vatican City           29
# 227  Western Sahara           10
# 228      MS Zaandam            9
# 229         Tokelau            5
# 230           China      503,302
#
#                                              3 4             5        6  \
# 0    1,125,558                                     100,449,206
# 1      530,726                                      44,148,472
# 2      163,463                                      39,056,393
# 3      163,965                                      37,104,300  +40,500
# 4      695,461                                      35,580,516
# ..                                         ... ..          ...      ...
# 226                                                         29
# ...

# %%
column_name=['country',
         'Totalcase',
         'Newcase',
         'TotalDeath',
         'Newdeath',
         'TotalRecovered',
         'Newrecovered',
         'Activecases',
         'Serious/critical',
         'Population']

# %%
len(columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(columns)
#
# NameError: name 'columns' is not defined

# %%
df.columns=column_name

# %%
df.head()
# Out:
#    country    Totalcase Newcase                                 TotalDeath  \
# 0      USA  103,583,983          1,125,558
# 1    India   44,681,884            530,726
# 2   France   39,453,006            163,463
# 3  Germany   37,622,357            163,965
# 4   Brazil   36,661,526            695,461
#
#   Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 0             100,449,206                2,009,219            4,454
# 1              44,148,472                    2,686              698
# 2              39,056,393                  233,150              869
# 3              37,104,300      +40,500     354,092            1,281
# 4              35,580,516                  385,549            8,318
#
#        Population
# 0    334,805,269
# 1  1,406,631,776
# 2     65,584,518
# 3     83,883,596
# 4    215,353,593

# %%
df.head(20)
# Out:
#         country    Totalcase  Newcase  \
# 0           USA  103,583,983
# 1         India   44,681,884
# 2        France   39,453,006
# 3       Germany   37,622,357
# 4        Brazil   36,661,526
# 5         Japan   31,471,011
# 6      S. Korea   29,861,234  +40,199
# 7         Italy   25,363,742
# 8            UK   24,243,393
# 9        Russia   21,860,902
# 10       Turkey   17,042,722
# 11        Spain   13,711,251
# 12      Vietnam   11,526,167
# 13    Australia   11,247,412
# 14    Argentina   10,024,095
# 15       Taiwan    9,225,106
# 16  Netherlands    8,577,856
# 17         Iran    7,562,755
# 18       Mexico    7,314,891
# 19    Indonesia    6,726,311
#
#                                    TotalDeath Newdeath TotalRecovered  \
# 0   1,125,558                                             100,449,206
# 1     530,726                                              44,148,472
# 2     163,463                                              39,056,393
# ...

# %%
df.tail()
# Out:
#             country Totalcase Newcase                             TotalDeath  \
# 226    Vatican City        29
# 227  Western Sahara        10              1
# 228      MS Zaandam         9              2
# 229         Tokelau         5
# 230           China   503,302          5,272
#
#     Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 226                      29                        0
# 227                       9                        0
# 228                       7                        0
# 229                                                5
# 230                 379,053                  118,977            7,557
#
#                                         Population
# 226                                           799
# 227                                       626,161
# 228
# 229                                         1,378
# 230  1,448,471,400

# %%
df.to_csv('covid_datajan11.csv',index=False)

# %%
# CSV = comma serprated value

# %% [markdown]
# # read csv file

# %%
df=pd.read_csv('covid_datajan11.csv')

# %%
df.head()
# Out:
#    country    Totalcase Newcase                                 TotalDeath  \
# 0      USA  103,583,983     NaN  1,125,558
# 1    India   44,681,884     NaN    530,726
# 2   France   39,453,006     NaN    163,463
# 3  Germany   37,622,357     NaN    163,965
# 4   Brazil   36,661,526     NaN    695,461
#
#    Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 0       NaN    100,449,206          NaN   2,009,219            4,454
# 1       NaN     44,148,472          NaN       2,686              698
# 2       NaN     39,056,393          NaN     233,150              869
# 3       NaN     37,104,300      +40,500     354,092            1,281
# 4       NaN     35,580,516          NaN     385,549            8,318
#
#        Population
# 0    334,805,269
# 1  1,406,631,776
# 2     65,584,518
# 3     83,883,596
# 4    215,353,593

# %% [markdown]
# # NaN means missing data

# %%
df.isnull()
# Out:
#      country  Totalcase  Newcase  TotalDeath  Newdeath  TotalRecovered  \
# 0      False      False     True       False      True           False
# 1      False      False     True       False      True           False
# 2      False      False     True       False      True           False
# 3      False      False     True       False      True           False
# 4      False      False     True       False      True           False
# ..       ...        ...      ...         ...       ...             ...
# 226    False      False     True       False      True           False
# 227    False      False     True       False      True           False
# 228    False      False     True       False      True           False
# 229    False      False     True       False      True            True
# 230    False      False     True       False      True           False
#
#      Newrecovered  Activecases  Serious/critical  Population
# ...

# %%
True + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %%
True + False
# Out:
# 1

# %%
df.isnull().sum()
# Out:
# country               0
# Totalcase             0
# Newcase             225
# TotalDeath            0
# Newdeath            229
# TotalRecovered       21
# Newrecovered        217
# Activecases          19
# Serious/critical     93
# Population            0
# dtype: int64

# %%
df.isnull().sum().plot.bar()
# Out:
# <AxesSubplot: >

# %%
df.isnull().sum().plot.pie()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Heatmap Plot of missing data

# %%
import seaborn as sns

# %%
df.isnull().transpose()
# Out:
#                     0      1      2      3      4      5      6      7    \
# country           False  False  False  False  False  False  False  False
# Totalcase         False  False  False  False  False  False  False  False
# Newcase            True   True   True   True   True   True  False   True
# TotalDeath        False  False  False  False  False  False  False  False
# Newdeath           True   True   True   True   True   True  False   True
# TotalRecovered    False  False  False  False  False  False  False  False
# Newrecovered       True   True   True  False   True   True  False   True
# Activecases       False  False  False  False  False  False  False  False
# Serious/critical  False  False  False  False  False  False  False  False
# Population        False  False  False  False  False  False  False  False
#
#                     8      9    ...    221    222    223    224    225    226  \
# country           False  False  ...  False  False  False  False  False  False
# ...

# %%
sns.heatmap(df.isnull().transpose())
# Out:
# <AxesSubplot: >

# %%
sns.heatmap([[30,29,47,80]])
# Out:
# <AxesSubplot: >

# %%
sns.heatmap([[0,1]])
# Out:
# <AxesSubplot: >

# %%
sns.heatmap([[True,False]])
# Out:
# <AxesSubplot: >

# %%
df.loc[df.country=="Nepal"]
# Out:
#    country  Totalcase Newcase                              TotalDeath  \
# 72   Nepal  1,001,056     NaN  12,020
#
#     Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 72       NaN        989,011          NaN          25              NaN
#
#      Population
# 72  30,225,582

# %%
df.loc[df.country=="Germany"]
# Out:
#    country   Totalcase Newcase                               TotalDeath  \
# 3  Germany  37,622,357     NaN  163,965
#
#    Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 3       NaN     37,104,300      +40,500     354,092            1,281
#
#     Population
# 3  83,883,596

# %%
df.loc[df.country=="Australia"]
# Out:
#       country   Totalcase Newcase                              TotalDeath  \
# 13  Australia  11,247,412     NaN  17,712
#
#     Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 13       NaN     11,146,950          NaN      82,750              102
#
#      Population
# 13  26,068,792

# %%
df.loc[df.country=="USA"]
# Out:
#   country    Totalcase Newcase                                 TotalDeath  \
# 0     USA  103,583,983     NaN  1,125,558
#
#    Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 0       NaN    100,449,206          NaN   2,009,219            4,454
#
#      Population
# 0  334,805,269

# %%
df['country']
# Out:
# 0                 USA
# 1               India
# 2              France
# 3             Germany
# 4              Brazil
#             ...
# 226      Vatican City
# 227    Western Sahara
# 228        MS Zaandam
# 229           Tokelau
# 230             China
# Name: country, Length: 231, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Scatterplot

# %%
import matplotlib.pyplot as plt

# %%
x=range(8,50,2)
y=[item * 0.1 for item in x]

# %%
plt.scatter(x=x,y=y)

# %%
plt.scatter(x=x,y=y, color='red')    #Scatterplot

# %% [markdown]
# # linechart

# %%
plt.plot(x,y,'o--',color='r')

# %% [markdown]
# # Insert CSV file in database

# %%
df.head()
# Out:
#    country    Totalcase Newcase                                 TotalDeath  \
# 0      USA  103,583,983     NaN  1,125,558
# 1    India   44,681,884     NaN    530,726
# 2   France   39,453,006     NaN    163,463
# 3  Germany   37,622,357     NaN    163,965
# 4   Brazil   36,661,526     NaN    695,461
#
#    Newdeath TotalRecovered Newrecovered Activecases Serious/critical  \
# 0       NaN    100,449,206          NaN   2,009,219            4,454
# 1       NaN     44,148,472          NaN       2,686              698
# 2       NaN     39,056,393          NaN     233,150              869
# 3       NaN     37,104,300      +40,500     354,092            1,281
# 4       NaN     35,580,516          NaN     385,549            8,318
#
#        Population
# 0    334,805,269
# 1  1,406,631,776
# 2     65,584,518
# 3     83,883,596
# 4    215,353,593

# %%
import sqlite3

# %%
con=sqlite3.connect('web.db')

# %%
cur=con.cursor()

# %%
cur

# %%
table_create_query=f"create table covid_data{(df.columns)}"

# %%
table_create_query
# Out:
# "create table covid_data('country', 'Totalcase', 'Newcase', 'TotalDeath', 'Newdeath', 'TotalRecovered', 'Newrecovered', 'Activecases', 'Serious/critical', 'Population')"

# %%
table_create_query=f"create table covid_data{tuple(df.columns)}"

# %%
table_create_query
# Out:
# "create table covid_data('country', 'Totalcase', 'Newcase', 'TotalDeath', 'Newdeath', 'TotalRecovered', 'Newrecovered', 'Activecases', 'Serious/critical', 'Population')"

# %%
cur.execute(table_create_query)  #table is created

# %%
datapoints=df.to_records(index=False).tolist()

# %%
datapoints
# Out:
# [('USA',
#   '103,583,983',
#   nan,
#   '1,125,558                                ',
#   nan,
#   '100,449,206',
#   nan,
#   '2,009,219',
#   '4,454',
#   '334,805,269 '),
#  ('India',
#   '44,681,884',
#   nan,
#   '530,726                                ',
#   nan,
#   '44,148,472',
#   nan,
#   '2,686',
#   '698',
#   '1,406,631,776 '),
#  ('France',
#   '39,453,006',
#   nan,
#   '163,463                                ',
#   nan,
#   '39,056,393',
#   nan,
#   '233,150',
#   '869',
#   '65,584,518 '),
#  ('Germany',
#   '37,622,357',
#   nan,
#   '163,965                                ',
#   nan,
#   '37,104,300',
#   '+40,500',
#   '354,092',
#   '1,281',
#   '83,883,596 '),
#  ('Brazil',
#   '36,661,526',
#   nan,
#   '695,461                                ',
#   nan,
#   '35,580,516',
#   nan,
#   '385,549',
#   '8,318',
#   '215,353,593 '),
#  ('Japan',
#   '31,471,011',
#   nan,
#   '62,963                                ',
#   nan,
#   '21,370,395',
#   nan,
# ...

# %%
insert_query="""
Insert into covid_data values(?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
"""

# %%
cur.executemany(insert_query,datapoints)

# %%
# read statemenr (select)

# %%
read="""
select * from covid_data where country = 'Nepal'
"""

# %%
cur.execute(read).fetchall()
# Out:
# [('Nepal',
#   '1,001,056',
#   None,
#   '12,020                                ',
#   None,
#   '989,011',
#   None,
#   '25',
#   None,
#   '30,225,582 ')]

# %%
import pandas as pd

# %%
pd.read_sql("select country from covid_data",con)
# Out:
#             country
# 0               USA
# 1             India
# 2            France
# 3           Germany
# 4            Brazil
# ..              ...
# 226    Vatican City
# 227  Western Sahara
# 228      MS Zaandam
# 229         Tokelau
# 230           China
#
# [231 rows x 1 columns]

# %%
pd.read_sql("select  country ,Totalcase, Population from covid_data",con)
# Out:
#             country    Totalcase  \
# 0               USA  103,583,983
# 1             India   44,681,884
# 2            France   39,453,006
# 3           Germany   37,622,357
# 4            Brazil   36,661,526
# ..              ...          ...
# 226    Vatican City           29
# 227  Western Sahara           10
# 228      MS Zaandam            9
# 229         Tokelau            5
# 230           China      503,302
#
#                                         Population
# 0                                     334,805,269
# 1                                   1,406,631,776
# 2                                      65,584,518
# 3                                      83,883,596
# 4                                     215,353,593
# ..                                             ...
# 226                                           799
# 227                                       626,161
# 228
# 229                                         1,378
# 230  1,448,471,400
#
# ...
